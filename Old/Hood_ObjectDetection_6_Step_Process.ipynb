# %% [markdown]
# # Object Detection
#
# This example program develops a HOG based object detector for things like faces, pedestrians, and any other semi-rigid object.  In particular, we go though the steps to train the kind of sliding window object detector first published by Dalal and Triggs in 2005 in the  paper Histograms of Oriented Gradients for Human Detection.
#
# It is similar to the method implemented in dlib (more optimized). However, this technique allows more control of the parameters.

# %% [markdown]
# ## Create the XML files
# DLIB requires images and bounding boxes around the labelled object. It has its own strructure for the XML files:
#
# <?xml version="1.0" encoding="UTF-8"?>
# <dataset>
#     <name>dataset containing bounding box labels on images</name>
#     <comment>created by BBTag</comment>
#     <tags>
#         <tag name="RunBib" color="#032585"/>
#     </tags>
#     <images>
#         <image file="B:/DataSets/2016_USATF_Sprint_TrainingDataset/_hsp3997.jpg">
#             <box top="945" left="887" width="85" height="53">
#                 <label>RunBib</label>
#             </box>
#             <box top="971" left="43" width="103" height="56">
#                 <label>RunBib</label>
#             </box>
#             <box top="919" left="533" width="100" height="56">
#                 <label>RunBib</label>
#             </box>
#
#         <image file="B:/DataSets/2016_USATF_Sprint_TrainingDataset/_hsp3989.jpg">
#             <box top="878" left="513" width="111" height="62">
#                 <label>my_label</label>
#             </box>
#
#    </images>
# </dataset>
# top: Top left y value
# height: Height (positive down)
# left: Top left x value
# width: Width (positive to the right)
#
# To create your own XML files you can use the imglab tool which can be found in the tools/imglab folder.  It is a simple graphical tool for labeling objects in images with boxes.  To see how to use it read the tools/imglab/README.txt file.  But for this example, we just use the training.xml file included with dlib.
#
# Its a two part process to load the tagger.
# 1.) typing the following command:
# #####    b:\HoodMachineLearning\dlib\tools\build\Release\imglab.exe -c mydataset.xml B:\HoodMachineLearning\datasets\MyImage
# 2.)
# ####     b:\HoodMachineLearning\dlib\tools\build\Release\imglab.exe -c mydataset.xml

# %% [markdown]
# ## Image pyramids and sliding windows
#
# The technique uses image pyramids and sliding windows to minimize the effect of object location and object size. The pyramid is a set of subsample images and the sliding window remains the same and moves from left to right and top to bottom of each scale of the image.
#
# ### Image Pyramids
# <img src="ImagePyramid.jpg">
#
# Note: Dalai and Triggs showed that performance is reduced if you apply gaussian smoothing at each layer==> ski this stip
#
# ### Sliding Window
#
# <img src="sliding_window_example.gif" loop=3>
#
# * It is common to use a stepSize of 4 to 8 pixels
# * windowSize is the size of the Kernal. An object detector will work best if the aspect ratio of the kernal is close to that of the desired object. Note: The sliding window size is also important for the HOG filter. For the HOG filter two parameters are important: <b>pixels_per_cell</b> and <b>cells_per_block </b>
#
# In order to avoid having to 'guess' at the best window size that will satisfy object detector requirements and HOG requirments, a "explore_dims.py" method is used.
#
# 1.) Meet object detection requirments: loads all the images and computes the average width, average height, and computes the aspect ratio from those values.
# 2.) Meet HOG requirments: Pyimage rule of thumb is to divide the above values by two (ie, 1/4th the average size)
#     * This reduces the size of the HOG feature vector
#     * By dividing by two, a nice balance is struck between HOG feature vector size and reasonable window size.
#     * Note: Our sliding_window dimension needs to be divisible by pixels_per_cell and cells_per_block so that the HOG descriptor will 'fit' into the window size
#     * Its common for 'pixels_per_cell' to be a multiple of 4 and cells_per_block in the set (1,2,3)
#     * Start with pixels_per_cell=(4,4) and cells_per_block=(2,2)
#     * For example, in the Pyimage example, average W: 184 and average H:62. Divide by 2 ==> 92,31
#     * Find values close to 92,31 that are divisible by 4 (and 2): 96,32  (Easy)
#     * OBSERVATION:  When defining the binding boxes, it is best if all are around the same size. This can be difficult.
#
# ### The 6 Step Framework
# 1. Sample P positive samples for your training data of the objects you want to detect. Extract HOG features from these objects.
#     * If given an a general image containing the object, bounding boxes will also need to be given that indicate the location of the image
# 2. Sample N negative samples that do not contain the object and extract HOG features. In general N>>P  (I'd suggest images similar in size and aspect ratio to the P samples. I'd also avoid the bounding boxes and make the entire image the negative image. Pyimagesearch recommends using the 13 Natural Scene Category of the vision.stanford.edu/resources_links.html page
# 3. Train a Linear Support Vector Machine (SVM) on the negative images (class 0) and positive image (class 1)
# 4. Hard Negative Mining - for the N negative images, apply Sliding window and test the classifier. Ideally, they should all return 0. If they return a 1 indicating an incorrect classification, add it to the training set (for the next round of re-training)
# 5. Re-train classifier using with the added images from Hard Negative Mining (Usually once is enough)
# 6. Apply against test dataset, define a box around regions of high probability, when finished with the image, find the boxed region with the highest probability using "non-maximum suppression" to removed redundant and overlapping bounding boxes and make that the final box.
#
# #### Note on DLIB library
# * Similar to the 6 step framework but uses the entire training image to get the P's (indicated by bounding boxes) and the N's (not containing bounding boxes).  Note: It looks like it is important that all of the objects are identified in the image. For example, when doing running bibs, I may ignore some bibs for some reasons (too small, partially blocked, too many). My guess is that these images should just simply be avoided. This technique eliminates steps 2, 4, and 5.
# * non-maximum supression is applied during the trainig phase helping to reduce false positives
# * dlib using a highly accurate SVM engine used to find the hyperplane separating the TWO classes.
#
#
# #### Use a JSON file to hold the hyper-parameters
# {
#
# "faces_folder": "B:\\DataSets\\2016_USATF_Sprint_TrainingDataset"
# "myTrainingFilename": "trainingset_small.xml"
# "myTestingFilename: "trainingset_small.xml"
# "myDetector": "detector.svm"
# }
#
# #### Load and Dump hdf5 file
# * hdf5 provides efficient data storage

# %%
from __future__ import print_function
from skimage import feature,exposure
import numpy as np
import cv2
import h5py
import simplejson as json
from sklearn.feature_extraction.image import extract_patches_2d
import argparse
import random
import os
from scipy import io
from lxml import etree
import math
import glob
#from imutils import paths
##import progressbar
#import cv2
#from pyimagesearch.object_detection import helpers
# import the necessary packages
# conda install -c anaconda simplejson
#import commentjson as json
#from pyimagesearch.object_detection import helpers
#from pyimagesearch.descriptors import HOG
#from pyimagesearch.utils import dataset
#from pyimagesearch.utils import Conf
##from imutils import paths
##from imutils import resize
#from scipy import io
##import progressbar
#import import_training_images_function2 as imp # Used to either import via Matlab file (CalTech) or XML (Scikit-learn)
#from skimage import exposure
#conda install -c anaconda progressbar
#from dlib import progressbar

# %%
class HOG:
	def __init__(self, orientations=12, pixelsPerCell=(4, 4), cellsPerBlock=(2, 2), normalize=True):
		# store the number of orientations, pixels per cell, cells per block, and
		# whether normalization should be applied to the image
		self.orientations = orientations
		self.pixelsPerCell = pixelsPerCell
		self.cellsPerBlock = cellsPerBlock
		self.normalize = normalize

	def describe(self, image):
		# compute Histogram of Oriented Gradients features
		hist = feature.hog(image, orientations=self.orientations, pixels_per_cell=self.pixelsPerCell,cells_per_block=self.cellsPerBlock, transform_sqrt=self.normalize)
		hist[hist < 0] = 0

		# return the histogram
		return hist

	def describe_and_return_HOGImage(self, image):
		# compute Histogram of Oriented Gradients features
		(hist,hogImage) = feature.hog(image, orientations=self.orientations, pixels_per_cell=self.pixelsPerCell,cells_per_block=self.cellsPerBlock, transform_sqrt=self.normalize, visualise=True)
		hist[hist < 0] = 0

		# return the histogram
		return hist,hogImage

# %%
# Referred to as helpers.py in PyImageSearch Class
def crop_ct101_bb(image, bb, padding=10, dstSize=(32, 32)):
	# unpack the bounding box, extract the ROI from the image, while taking into account
	# the supplied offset
	(y, h, x, w) = bb # Looks like this is y1,y2,x1,x2
	#print("y,h,x,w ={} {} {} {}".format(y,h,x,w))
	(x, y) = (max(x - padding, 0), max(y - padding, 0))
	roi = image[y:h + padding, x:w + padding]
	#print("ROI: {}".format(roi))
	# resize the ROI to the desired destination size
	# It is important to resize the roi in order to keep the final feature vector the same size	
	roi = cv2.resize(roi, dstSize, interpolation=cv2.INTER_AREA)

	# return the ROI
	return roi

def pyramid(image, scale=1.5, minSize=(30, 30)):
	# yield the original image
	yield image

	# keep looping over the pyramid
	while True:
		# compute the new dimensions of the image and resize it
		w = int(image.shape[1] / scale)
		h = int(image.shape[0] / scale)        
		#image = imutils.resize(image, width=w)
		image = cv2.resize(image, (w,h))

		# if the resized image does not meet the supplied minimum
		# size, then stop constructing the pyramid
		if image.shape[0] < minSize[1] or image.shape[1] < minSize[0]:
			break

		# yield the next image in the pyramid
		yield image

def sliding_window(image, stepSize, windowSize):
	# slide a window across the image
	for y in range(0, image.shape[0], stepSize):
		for x in range(0, image.shape[1], stepSize):
			# yield the current window
			#print("X: {}".format(x))
			#print("Y: {}".format(y))
			#print("Window Shape Check: {}".format(image.shape[:2]))
			yield (x, y, image[y:y + windowSize[1], x:x + windowSize[0]])

# %%
class ObjectDetector:
	def __init__(self, model, desc):
		# store the classifier and HOG descriptor
		self.model = model
		self.desc = desc

	def detect(self, image, winDim, winStep=4, pyramidScale=1.5, minProb=0.7):
		# initialize the list of bounding boxes and associated probabilities
		boxes = []
		probs = []
		
		# Calculate number of loops
        testimage=image
        for i,layer in enumerate(pyramid(image, scale=pyramidScale, minSize=winDim)):
            scale = testmage.shape[0] / float(layer.shape[0])
		# loop over the image pyramid
		for i,layer in enumerate(pyramid(image, scale=pyramidScale, minSize=winDim)):
			
			# determine the current scale of the pyramid
			scale = image.shape[0] / float(layer.shape[0])
			print("[INFO] Investigating layer {} at scale: {}".format(i,scale))
			# loop over the sliding windows for the current pyramid layer
			counter =0
			for (x, y, window) in sliding_window(layer, winStep, winDim):
				# grab the dimensions of the window
				(winH, winW) = window.shape[:2]
				counter = counter+1
				# ensure the window dimensions match the supplied sliding window dimensions
				if winH == winDim[1] and winW == winDim[0]:
					# extract HOG features from the current window and classifiy whether or
					# not this window contains an object we are interested in
					#print("[INFO] Extracting HOG features")
					features = self.desc.describe(window).reshape(1, -1)
					#print("Object Detector Feature Size: {}".format(features.shape))
					prob = self.model.predict_proba(features)[0][1]
					if counter % 1000 ==0:
						print("[INFO] Model Probability: {}  Loop: {}   KeyPoint Top Left Corner (x,y) {}".format(prob, counter,[x,y]))

					# check to see if the classifier has found an object with sufficient
					# probability
					if prob > minProb:
						##print("[INFO] ********** Found a candidate! **************")
						# compute the (x, y)-coordinates of the bounding box using the current
						# scale of the image pyramid
						(startX, startY) = (int(scale * x), int(scale * y))
						endX = int(startX + (scale * winW))
						endY = int(startY + (scale * winH))

						# update the list of bounding boxes and probabilities
						boxes.append((startX, startY, endX, endY))
						probs.append(prob)

		# return a tuple of the bounding boxes and probabilities
		return (boxes, probs)

# %%
def non_max_suppression(boxes, probs, overlapThresh):
	# if there are no boxes, return an empty list
	if len(boxes) == 0:
		return []

	# if the bounding boxes are integers, convert them to floats -- this is important since
	# we'll be doing a bunch of divisions
	if boxes.dtype.kind == "i":
		boxes = boxes.astype("float")

	# initialize the list of picked indexes
	pick = []

	# grab the coordinates of the bounding boxes
	x1 = boxes[:, 0]
	y1 = boxes[:, 1]
	x2 = boxes[:, 2]
	y2 = boxes[:, 3]

	# compute the area of the bounding boxes and sort the bounding boxes by their associated
	# probabilities
	area = (x2 - x1 + 1) * (y2 - y1 + 1)
	idxs = np.argsort(probs)

	# keep looping while some indexes still remain in the indexes list
	while len(idxs) > 0:
		# grab the last index in the indexes list and add the index value to the list of
		# picked indexes
		last = len(idxs) - 1
		i = idxs[last]
		pick.append(i)

		# find the largest (x, y) coordinates for the start of the bounding box and the
		# smallest (x, y) coordinates for the end of the bounding box
		xx1 = np.maximum(x1[i], x1[idxs[:last]])
		yy1 = np.maximum(y1[i], y1[idxs[:last]])
		xx2 = np.minimum(x2[i], x2[idxs[:last]])
		yy2 = np.minimum(y2[i], y2[idxs[:last]])

		# compute the width and height of the bounding box
		w = np.maximum(0, xx2 - xx1 + 1)
		h = np.maximum(0, yy2 - yy1 + 1)

		# compute the ratio of overlap
		overlap = (w * h) / area[idxs[:last]]

		# delete all indexes from the index list that have overlap greater than the
		# provided overlap threshold
		idxs = np.delete(idxs, np.concatenate(([last],
			np.where(overlap > overlapThresh)[0])))

	# return only the bounding boxes that were picked
	return boxes[pick].astype("int")

# %%
def dump_dataset(data, labels, path, datasetName, writeMethod="w"):
    # open the database, create the dataset, write the data and labels to dataset,
    # and then close the database
    with h5py.File(path, writeMethod) as db:
        dataset = db.create_dataset(datasetName, (len(data), len(data[0]) + 1), dtype="float")
        dataset[0:len(data)] = np.c_[labels, data]
        db.close()
    print("Finished Dumping Data into: ".format(path))

def load_dataset(path, datasetName):
    # open the database, grab the labels and data, then close the dataset
    with h5py.File(path, "r") as db:
        (labels, data) = (db[datasetName][:, 0], db[datasetName][:, 1:])
        db.close()

    # return a tuple of the data and labels
    return (data, labels)

# %%
#list(db.keys())

# %%
class Conf:
	def __init__(self, confPath):
		# load and store the configuration and update the object's dictionary
		conf = json.loads(open(confPath).read())
		self.__dict__.update(conf)

	def __getitem__(self, k):
		# return the value associated with the supplied key
		return self.__dict__.get(k, None)

# %%
def import_with_Matlab(conf,hog,SW):
    data = []   
    labels = []
    # grab the set of ground-truth images and select a percentage of them for training
    #trnPaths = list(paths.list_images(conf["image_dataset"]))
    trnPaths = list(os.listdir(conf["image_dataset"]))
    trnPaths = random.sample(trnPaths, int(len(trnPaths) * conf["percent_gt_images"]))
    print("[INFO] describing training ROIs...")
    # setup the progress bar
    #widgets = ["Extracting: ", progressbar.Percentage(), " ", progressbar.Bar(), " ", progressbar.ETA()]
    #pbar = progressbar.ProgressBar(maxval=len(trnPaths), widgets=widgets).start()
    # loop over the training paths
    for (i, trnPath) in enumerate(trnPaths):
        # load the image, convert it to grayscale, and extract the image ID from the path
        image = cv2.imread(trnPath)
        image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
        imageID = trnPath[trnPath.rfind("_") + 1:].replace(".jpg", "")
        
        # load the annotation file associated with the image and extract the bounding box
        p = "{}/annotation_{}.mat".format(conf["image_annotations"], imageID)
        bb = io.loadmat(p)["box_coord"][0] #(y,h,x,w)
        # The next line crops the image to only the object. Because of this, no scanning is required
        # and the image size can simply be set to the scanning size (plus offset) so that only one scan is needed
        #roi = crop_ct101_bb(image, bb, padding=conf["offset_padding"], dstSize=tuple(conf["window_dim"]))
        roi = crop_ct101_bb(image, bb, padding=conf["offset_padding"], dstSize=SW)
        # define the list of ROIs that will be described, based on whether or not the
        # horizontal flip of the image should be used
        rois = (roi, cv2.flip(roi, 1)) if conf["use_flip"] else (roi,)
        
        # loop over the ROIs
        for roi in rois:
        	# extract features from the ROI and update the list of features and labels
        	features = hog.describe(roi)
        	data.append(features)
        	labels.append(1)
    
        # update the progress bar
        #	pbar.update(i)
    return  data,labels



def import_from_XML(conf,hog,SW):
    data = []   
    labels = []
    ##print("Importing: {}".format(conf["image_dataset_XML"])) 
    doc = etree.parse(conf["image_dataset_XML"])
    MyXML=doc.find('images')
    ## widgets = ["Extracting: ", progressbar.Percentage(), " ", progressbar.Bar(), " ", progressbar.ETA()]
    ## pbar = progressbar.ProgressBar(maxval=len(doc.xpath(".//*")), widgets=widgets).start()
    # loop over the training paths
    #for (i, info) in enumerate(MyXML):
    i = 0
    for info in MyXML:
        # load the image, convert it to grayscale, and extract the image ID from the path
        try:
            imagename=conf["image_dataset"] + "\\" + info.get('file')
            #print("Working on file: {}".format(imagename))
            image = cv2.imread(imagename)
            #cv2.imshow("My Image",image)
            #cv2.waitKey(0)
            image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
            y=int(info[0].get('top'))
            x=int(info[0].get('left'))
            w=int(info[0].get('width'))
            h=int(info[0].get('height')) 
            bb =[int(y),int(y)+int(h),int(x),int(x)+int(w)]  # [ y h x w] % (Look into h may be top and top/y may actually be h
            #print("bb: {}".format(bb))
            #newimage=image[y:y+h,x:x+w]
            #roi = crop_ct101_bb(image, bb, padding=conf["offset"], dstSize=tuple(conf["window_dim"]))
            # The next line crops the image to only the object. Because of this, no scanning is required
            # and the image size can simply be set to the scanning size (plus offset) so that only one scan is needed
            #roi = crop_ct101_bb(image, bb, padding=conf["offset_padding"], dstSize=tuple(conf["image_resized"]))
            roi = crop_ct101_bb(image, bb, padding=conf["offset_padding"], dstSize=SW)
            ##print("The image size is {}.".format(roi.shape))
            ##cv2.imshow(imagename,roi)
            ##cv2.waitKey(0)         
            # define the list of ROIs that will be described, based on whether or not the
            # horizontal flip of the image should be used
            if conf["use_flip"]:
                rois = (roi, cv2.flip(roi, 1))
            else:
                rois = (roi,)
                        
            # loop over the ROIs
            for roi in rois:
                # extract features from the ROI and update the list of features and labels
                features = hog.describe(roi)
                data.append(features)
                labels.append(1)
        
                # update the progress bar
                #pbar.update(i)
        except:
            print("Issue with file:  {}".format(imagename))
            
        i=i+1
        
    return  data,labels

# %%
def GetAvgDimensions(conf):
    doc = etree.parse(conf["image_dataset_XML"])
    MyXML=doc.find('images')
    widths = []
    heights = []
    i = 0
    for info in MyXML:
        imagename=conf["image_dataset"] + "\\" + info.get('file')
        image = cv2.imread(imagename)
        #print("Reading {}".format(imagename))
        widths.append(int(info[0].get('width')))
        heights.append(int(info[0].get('height')) )

    (avgWidth, avgHeight) = (np.mean(widths), np.mean(heights))
    (stdW,stdH)=(np.std(widths),np.std(heights))
    #print("The length of widths is {}".format(len(widths)))
    newW=math.ceil(int(avgWidth/2)/4)*4
    newH=math.ceil(int(avgHeight/2)/4)*4
    print("[INFO] avg. width: {:.2f} +/- {:.2f}".format(avgWidth,stdW))
    print("[INFO] avg. height: {:.2f} +/- {:.2f}".format(avgHeight,stdH))
    print("[INFO] aspect ratio: {:.2f}".format(avgWidth / avgHeight))
    print("[INFO] The recommended Sliding Window Size is W:{}  H:{}".format(newW,newH))
    print("[INFO] Sliding Window Aspect Ratio {:.2f}".format(newW / newH))
    return tuple([newW,newH])

# %%
def Hard_Negative_Mining(conf,SW):
    data = []

    # load the classifier, then initialize the Histogram of Oriented Gradients descriptor
    # and the object detector
    #model = cPickle.loads(open(conf["classifier_path"]).read())
    pfile=conf["classifier_path"]
    with open(pfile, 'rb') as f:
        model = cPickle.load(f, encoding='bytes')
    f.close()
    hog = HOG(orientations=conf["orientations"], pixelsPerCell=tuple(conf["pixels_per_cell"]),
    cellsPerBlock=tuple(conf["cells_per_block"]), normalize=conf["normalize"])
    od = ObjectDetector(model, hog)

    # grab the set of distraction paths and randomly sample them
    #dstPaths = list(paths.list_images(conf["image_distractions"]))
    dstPaths=glob.glob(conf["image_distractions"] + "\\*.jpg")
    dstPaths = random.sample(dstPaths, conf["hn_num_distraction_images"])

    # setup the progress bar
    #widgets = ["Mining: ", progressbar.Percentage(), " ", progressbar.Bar(), " ", progressbar.ETA()]
    #pbar = progressbar.ProgressBar(maxval=len(dstPaths), widgets=widgets).start()

    # loop over the distraction paths
    for (i, imagePath) in enumerate(dstPaths):
        # load the image and convert it to grayscale
        image = cv2.imread(imagePath)
        gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
        print("[INFO] Scanning file: {}".format(imagePath))
        # detect objects in the image
        #(boxes, probs) = od.detect(gray, conf["window_dim"], winStep=conf["hn_window_step"],
        #pyramidScale=conf["hn_pyramid_scale"], minProb=conf["hn_min_probability"])
        (boxes, probs) = od.detect(gray, SW, winStep=conf["hn_window_step"],
            pyramidScale=conf["hn_pyramid_scale"], minProb=conf["hn_min_probability"])
        # loop over the bounding boxes
        minprob = conf["hn_min_probability"]
        print("[INFO] {} boxes were found with a probablility > {}".format(len(boxes),conf["hn_min_probability"]))
        for (prob, (startX, startY, endX, endY)) in zip(probs, boxes):
            # extract the ROI from the image, resize it to a known, canonical size, extract
            # HOG features from teh ROI, and finally update the data
            #roi = cv2.resize(gray[startY:endY, startX:endX], tuple(conf["window_dim"]),interpolation=cv2.INTER_AREA)
            roi = cv2.resize(gray[startY:endY, startX:endX],SW,interpolation=cv2.INTER_AREA)
            features = hog.describe(roi)
            ##data.append(np.hstack([[prob], features])) # This line gave errors
            data.append(features)

    labels = [-1] * len(data)
    # update the progress bar
    #pbar.update(i)

    # sort the data points by confidence
    #pbar.finish()
    ###print("[INFO] sorting by probability...")
    ###data = np.array(data)
    ###data = data[data[:, 0].argsort()[::-1]]

    # dump the dataset to file
    print("[INFO] dumping hard negatives to file...")
    #dump_dataset(data[:, 1:], [-1] * len(data), conf["features_path"], "hard_negatives",writeMethod="a")

    if len(data)>0 :
        dump_dataset(data, labels, conf["features_path"], "hard_negatives",writeMethod="a")
    else: 
        print("No Hard-Negatives were found in the images provided")

# %% [markdown]
# # Begin HOG Feature Extraction for Positive images and Negative images

# %%
myJSONFile = os.getcwd() + "\\conf\\TrackBibs.json"
conf = Conf(myJSONFile)

# %%
SW=GetAvgDimensions(conf)
# Out:
# [INFO] avg. width: 174.21 +/- 97.51
# [INFO] avg. height: 125.54 +/- 73.02
# [INFO] aspect ratio: 1.39
# [INFO] The recommended Sliding Window Size is W:88  H:64
# [INFO] Sliding Window Aspect Ratio 1.38

# %%
# initialize the HOG descriptor along with the list of data and labels
hog = HOG(orientations=conf["orientations"], pixelsPerCell=tuple(conf["pixels_per_cell"]), 
          cellsPerBlock=tuple(conf["cells_per_block"]), normalize=conf["normalize"])

# %% [markdown]
# ## Begin HOG feature extraction of Positive Images

# %%
print("[INFO] Begin HOG Feature Extraction of Positive Images...")
print("Image XML File:")
print(conf["image_dataset_XML"])
print("Image files are located in:")
print(conf["image_dataset"])
# Open dataset images and extract features for different scales. The extension will
# determine how the bounding box information is presented (.XML (as used by DLIB), or .Mat (as used by CalTech))
tmp=os.path.splitext(conf["image_dataset_XML"]) #TODO  Need to come back to
if tmp[1]==".xml":
    print("Using XML Format")
# Run ExtractImageInfoFromXML_Hood.py
    # Note: The sliding window size is calculated from the images. The value in the json file is bypassed
    data,labels=import_from_XML(conf,hog,SW)
else:
# Run ExtractImageInfoFromMatlab_Hood.py
    print("Using Matlab Format")
    data,labels=import_with_Matlab(conf,hog,SW)
lenPositiveFeatures=len(data)
print("Finished")    
print("There are {} feature vectors and each vector contains {} elements for a total of {} elements.".format(len(data),len(data[0]),len(data) * len(data[0])))
# Out:
# [INFO] Begin HOG Feature Extraction of Positive Images...
# Image XML File:
# M:\DataSets\2016_USATF_Sprint_TrainingDataset\sprints_large.xml
# Image files are located in:
# M:\DataSets\2016_USATF_Sprint_TrainingDataset
# Using XML Format
# Finished
# There are 67 feature vectors and each vector contains 11340 elements for a total of 759780 elements.

# %% [markdown]
# ## Begin HOG feature extraction of Negative Images

# %%
print("[INFO] Begin HOG Feature Extraction of Negative Images...")
#dstPaths = list(os.listdir(conf["image_distractions"]))
dstPaths=glob.glob(conf["image_distractions"] + "\\*.jpg")
#dstPaths.append(glob.glob(conf["image_distractions2"] + "\\*.jpg"))
#dstPaths.append(glob.glob(conf["image_distractions3"] + "\\*.jpg"))
#dstPaths.append(glob.glob(conf["image_distractions4"] + "\\*.jpg"))
#print(files)

#widgets = ["Extracting: ", progressbar.Percentage(), " ", progressbar.Bar(), " ", progressbar.ETA()]
#pbar = progressbar.ProgressBar(maxval=conf["num_distraction_images"], widgets=widgets).start()
# loop over the desired number of distraction images
patches=[]
for i in np.arange(0, conf["num_distraction_images"]):
    # randomly select a distraction images, load it, convert it to grayscale, and
    # then extract random pathces from the image
    image = cv2.imread(random.choice(dstPaths))
    ##image = resize(image,width=int(conf["max_image_width"]))
    image = cv2.resize(image,SW)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    patches.append(image)
    # extract_patches_2d is a convienent ROI sampling implementation in scikit-learn
    ##patches = extract_patches_2d(image, tuple(conf["window_dim"]),max_patches=conf["num_distractions_per_image"])
    ##patches = extract_patches_2d(image, tuple(SW),max_patches=conf["num_distractions_per_image"])
# loop over the patches,
for patch in patches:
    # extract features from the patch, then update teh data and label list
    ##features = hog.describe(patch)
    features = hog.describe(patch)
    data.append(features)
    labels.append(-1)


    # update the progress bar
    #pbar.update(i)
print("Finished")    
print("There are now {} feature vectors and each vector contains {} elements for a total of {} elements.".format(len(data),len(data[0]),len(data) * len(data[0])))
print("{} Positive features and {} Negative features".format(lenPositiveFeatures,len(patches)))
# Out:
# [INFO] Begin HOG Feature Extraction of Negative Images...
# Finished
# There are now 117 feature vectors and each vector contains 11340 elements for a total of 1326780 elements.
# 67 Positive features and 50 Negative features

# %%
# dump the dataset to file
#pbar.finish()
print("[INFO] dumping features and labels to file...")
MyFeaturePath=conf["features_path"]
print("Feature data is saved in {}".format(MyFeaturePath))
dump_dataset(data, labels, MyFeaturePath, "features")
# Out:
# [INFO] dumping features and labels to file...
# Feature data is saved in M:\DataSets\2016_USATF_Sprint_TrainingDataset\SprintBibPhotosLarge.hdf5
# Finished Dumping Data into:

# %% [markdown]
# ## Begin Training SVM using saved HOG feature vectors

# %% [markdown]
# The 'C' parameter for the SVM measures how 'strict' SVM is. Larger values indicate a tolerance for fewer mistakes. While this can lead to higher accuracy on the training data, it could lead to overfitting. Smaller values lead to a 'soft-classifier'. Initially, we let it make many mistakes knowing downstream, hard negative mining will help rectify many of these mistakes.

# %%
from sklearn.svm import SVC
from sklearn.metrics import classification_report
from sklearn.cross_validation import train_test_split
from sklearn.grid_search import GridSearchCV
from sklearn.svm import LinearSVC 
import _pickle as cPickle
def train_model(conf,useHardNegatives):
    # load the configuration file and the initial dataset
    print("[INFO] loading dataset...")
    #conf = Conf(args["conf"])
    (data, labels) = load_dataset(conf["features_path"], "features") # contains images labled as good (+1) and bad (-1)
    print("Example of a data point. Feature: {} and Label {}".format(data[0],labels[0]))
    if useHardNegatives > 0:
        print("[INFO] loading hard negatives...")
        (hardData, hardLabels) = load_dataset(conf["features_path"], "hard_negatives")
        data = np.vstack([data, hardData])  # Combine data with hardData
        labels = np.hstack([labels, hardLabels])

    # Determine an optimal value for C
    params = {"C": [.1, 1.0, 10.0, 100, 1000, 10000.0]}
    ### Note: I cannot use params here. I would first have to extract the features for the
    modeltemp = GridSearchCV(LinearSVC(random_state=42),params,cv=3)
    modeltemp.fit(data,labels)
    print("[INFO] best hyperparameters: {}".format(modeltemp.best_params_))

    # train the svd classifier
    print("[INFO] training classifier...")
    model = SVC(kernel="linear", C=conf["C"], probability=True, random_state=42)
    model.fit(data, labels)
    print(classification_report(labels,model.predict(data)))

    # dump the classifier to file
    print("[INFO] dumping classifier...")
    myFileName=conf["classifier_path"]
    f = open(conf["classifier_path"], "wb")
    f.write(cPickle.dumps(model))
    f.close()
    print("Finished.  SVD is saved as: {}".format(myFileName))

def test_model(conf,image_Filename,SW):
    # load the classifier, then initialize the Histogram of Oriented Gradients descriptor
    # and the object detector
    # load the image and convert it to grayscale
    image = cv2.imread(image_Filename)
    #image = imutils.resize(image,width=int(conf["max_image_width"]))
    #image = imutils.resize(image,SW) # resizes to match size used during training
    #image = cv2.resize(image, width=min(260, image.shape[1]))
    minwidth=min(int(conf["max_image_width"]), image.shape[0])
    minheight=min(int(conf["max_image_width"]), image.shape[1])
    image = cv2.resize(image, (minwidth,minheight)) 
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    #print("Image size: {}".format(gray.shape))
    pfile=conf["classifier_path"]
    with open(pfile, 'rb') as f:
        model = cPickle.load(f, encoding='bytes')
    f.close()
  
    #hog = HOG(orientations=conf["orientations"], pixelsPerCell=tuple(conf["pixels_per_cell"]), 
    #      cellsPerBlock=tuple(conf["cells_per_block"]), normalize=conf["normalize"])
    #print(hog)
   
    od = ObjectDetector(model, hog)

    print(od)

    # detect objects in the image and apply non-maxima suppression to the bounding boxes
    print("Detecting the object")
    #winDim=conf["sliding_window_dim"]
    winDim=SW # Recall, the sliding window dimensions are computed.
    winStep=conf["window_step"]
    pyramidScale=conf["pyramid_scale"]
    minProb=conf["min_probability"]
    (boxes, probs) = od.detect(gray,winDim,winStep,pyramidScale,minProb)
    pick = non_max_suppression(np.array(boxes), probs, conf["overlap_thresh"])
    orig = image.copy()
    print("Finished detecting the object")  
    ##print("boxes: {}".format(boxes))

    if len(boxes) <1 :
        print("The object was not found")
    else:
        # loop over the original bounding boxes and draw them
        for (startX, startY, endX, endY) in boxes:
            cv2.rectangle(orig, (startX, startY), (endX, endY), (0, 0, 255), 2)

    # loop over the allowed bounding boxes and draw them
    for (startX, startY, endX, endY) in pick:
        cv2.rectangle(image, (startX, startY), (endX, endY), (0, 255, 0), 2)

    # show the output images
    cv2.imshow("Original", orig)
    cv2.imshow("Image", image)
    cv2.waitKey(0)

# %%
train_model(conf,0)
# Out:
# [INFO] loading dataset...
# Example of a data point. Feature: [ 0.03051709  0.00742838  0.04882491 ...,  0.00128204  0.          0.        ] and Label 1.0
# [INFO] best hyperparameters: {'C': 0.1}
# [INFO] training classifier...
#              precision    recall  f1-score   support
#
#        -1.0       0.98      1.00      0.99        50
#         1.0       1.00      0.99      0.99        67
#
# avg / total       0.99      0.99      0.99       117
#
# [INFO] dumping classifier...
# Finished.  SVD is saved as: M:\DataSets\2016_USATF_Sprint_TrainingDataset\svm_model.cpickle

# %%
Hard_Negative_Mining(conf,SW)
# Out:
# [INFO] Scanning file: M:\DataSets\Caltech256\256_ObjectCategories\013.birdbath\013_0094.jpg
# [INFO] Investigating layer 0 at scale: 1.0
# [INFO] Model Probability: 0.004307037308012901  Loop: 1000   KeyPoint Top Left Corner (x,y) [1948, 4]
# [INFO] Model Probability: 0.009787606549165448  Loop: 2000   KeyPoint Top Left Corner (x,y) [1852, 12]
# [INFO] Model Probability: 0.03887817133916525  Loop: 3000   KeyPoint Top Left Corner (x,y) [1756, 20]
# [INFO] Model Probability: 0.004232632843576445  Loop: 4000   KeyPoint Top Left Corner (x,y) [1660, 28]
# [INFO] Model Probability: 0.01672895453273518  Loop: 5000   KeyPoint Top Left Corner (x,y) [1564, 36]
# [INFO] Model Probability: 0.0051836791694279275  Loop: 6000   KeyPoint Top Left Corner (x,y) [1468, 44]
# [INFO] Model Probability: 0.010031230230064624  Loop: 7000   KeyPoint Top Left Corner (x,y) [1372, 52]
# [INFO] Model Probability: 0.009802972161800688  Loop: 8000   KeyPoint Top Left Corner (x,y) [1276, 60]
# [INFO] Model Probability: 0.0051236713593604145  Loop: 9000   KeyPoint Top Left Corner (x,y) [1180, 68]
# [INFO] Model Probability: 0.008845254421691371  Loop: 10000   KeyPoint Top Left Corner (x,y) [1084, 76]
# [INFO] Model Probability: 0.0058356658806835125  Loop: 11000   KeyPoint Top Left Corner (x,y) [988, 84]
# [INFO] Model Probability: 0.009257967491277193  Loop: 12000   KeyPoint Top Left Corner (x,y) [892, 92]
# [INFO] Model Probability: 0.01091622348078425  Loop: 13000   KeyPoint Top Left Corner (x,y) [796, 100]
# [INFO] Model Probability: 0.01542757474139428  Loop: 14000   KeyPoint Top Left Corner (x,y) [700, 108]
# [INFO] Model Probability: 0.008599601153594835  Loop: 15000   KeyPoint Top Left Corner (x,y) [604, 116]
# [INFO] Model Probability: 0.019722200617623153  Loop: 16000   KeyPoint Top Left Corner (x,y) [508, 124]
# [INFO] Model Probability: 0.012137338368642035  Loop: 17000   KeyPoint Top Left Corner (x,y) [412, 132]
# [INFO] Model Probability: 0.016703246594825014  Loop: 18000   KeyPoint Top Left Corner (x,y) [316, 140]
# [INFO] Model Probability: 0.0037985397098786937  Loop: 19000   KeyPoint Top Left Corner (x,y) [220, 148]
# [INFO] Model Probability: 0.030115435494757904  Loop: 20000   KeyPoint Top Left Corner (x,y) [124, 156]
# [INFO] Model Probability: 0.011189946054120686  Loop: 21000   KeyPoint Top Left Corner (x,y) [28, 164]
# [INFO] Model Probability: 0.01456607674948781  Loop: 23000   KeyPoint Top Left Corner (x,y) [1884, 176]
# [INFO] Model Probability: 0.03455205154078904  Loop: 24000   KeyPoint Top Left Corner (x,y) [1788, 184]
# [INFO] Model Probability: 0.010169789226383088  Loop: 25000   KeyPoint Top Left Corner (x,y) [1692, 192]
# [INFO] Model Probability: 0.012711852802145183  Loop: 26000   KeyPoint Top Left Corner (x,y) [1596, 200]
# [INFO] Model Probability: 0.0028071947881898327  Loop: 27000   KeyPoint Top Left Corner (x,y) [1500, 208]
# [INFO] Model Probability: 0.009769740997680172  Loop: 28000   KeyPoint Top Left Corner (x,y) [1404, 216]
# [INFO] Model Probability: 0.008923109363154916  Loop: 29000   KeyPoint Top Left Corner (x,y) [1308, 224]
# [INFO] Model Probability: 0.008967739356115648  Loop: 30000   KeyPoint Top Left Corner (x,y) [1212, 232]
# [INFO] Model Probability: 0.03037770974916172  Loop: 31000   KeyPoint Top Left Corner (x,y) [1116, 240]
# [INFO] Model Probability: 0.030516117961052264  Loop: 32000   KeyPoint Top Left Corner (x,y) [1020, 248]
# [INFO] Model Probability: 0.032528833999364425  Loop: 33000   KeyPoint Top Left Corner (x,y) [924, 256]
# [INFO] Model Probability: 0.004733994668213148  Loop: 34000   KeyPoint Top Left Corner (x,y) [828, 264]
# [INFO] Model Probability: 0.0075199621941458355  Loop: 35000   KeyPoint Top Left Corner (x,y) [732, 272]
# [INFO] Model Probability: 0.01950374193518851  Loop: 36000   KeyPoint Top Left Corner (x,y) [636, 280]
# [INFO] Model Probability: 0.03385102963413203  Loop: 37000   KeyPoint Top Left Corner (x,y) [540, 288]
# [INFO] Model Probability: 0.0067448743851905085  Loop: 38000   KeyPoint Top Left Corner (x,y) [444, 296]
# [INFO] Model Probability: 0.0064478557850854625  Loop: 39000   KeyPoint Top Left Corner (x,y) [348, 304]
# [INFO] Model Probability: 0.006793125799704193  Loop: 40000   KeyPoint Top Left Corner (x,y) [252, 312]
# [INFO] Model Probability: 0.004833902907752281  Loop: 41000   KeyPoint Top Left Corner (x,y) [156, 320]
# [INFO] Model Probability: 0.006765298703243443  Loop: 42000   KeyPoint Top Left Corner (x,y) [60, 328]
# [INFO] Model Probability: 0.007956145940197577  Loop: 44000   KeyPoint Top Left Corner (x,y) [1916, 340]
# [INFO] Model Probability: 0.0032040149954815646  Loop: 45000   KeyPoint Top Left Corner (x,y) [1820, 348]
# [INFO] Model Probability: 0.005238470942895327  Loop: 46000   KeyPoint Top Left Corner (x,y) [1724, 356]
# [INFO] Model Probability: 0.0023498456894461327  Loop: 47000   KeyPoint Top Left Corner (x,y) [1628, 364]
# [INFO] Model Probability: 0.004306750251117937  Loop: 48000   KeyPoint Top Left Corner (x,y) [1532, 372]
# [INFO] Model Probability: 0.010040758459872278  Loop: 49000   KeyPoint Top Left Corner (x,y) [1436, 380]
# [INFO] Model Probability: 0.0029680708224222086  Loop: 50000   KeyPoint Top Left Corner (x,y) [1340, 388]
# [INFO] Model Probability: 0.012746601483750248  Loop: 51000   KeyPoint Top Left Corner (x,y) [1244, 396]
# [INFO] Model Probability: 0.016839843810709836  Loop: 52000   KeyPoint Top Left Corner (x,y) [1148, 404]
# [INFO] Model Probability: 0.031304541644319374  Loop: 53000   KeyPoint Top Left Corner (x,y) [1052, 412]
# [INFO] Model Probability: 0.006172511729161886  Loop: 54000   KeyPoint Top Left Corner (x,y) [956, 420]
# [INFO] Model Probability: 0.005168102692169419  Loop: 55000   KeyPoint Top Left Corner (x,y) [860, 428]
# [INFO] Model Probability: 0.006500314761294418  Loop: 56000   KeyPoint Top Left Corner (x,y) [764, 436]
# [INFO] Model Probability: 0.16578141682532047  Loop: 57000   KeyPoint Top Left Corner (x,y) [668, 444]
# [INFO] Model Probability: 0.022014323942742654  Loop: 58000   KeyPoint Top Left Corner (x,y) [572, 452]
# [INFO] Model Probability: 0.0070600515049172195  Loop: 59000   KeyPoint Top Left Corner (x,y) [476, 460]
# [INFO] Model Probability: 0.015453573171711914  Loop: 60000   KeyPoint Top Left Corner (x,y) [380, 468]
# [INFO] Model Probability: 0.004990031462609104  Loop: 61000   KeyPoint Top Left Corner (x,y) [284, 476]
# [INFO] Model Probability: 0.0047400667946004005  Loop: 62000   KeyPoint Top Left Corner (x,y) [188, 484]
# [INFO] Model Probability: 0.0038947658815475504  Loop: 63000   KeyPoint Top Left Corner (x,y) [92, 492]
# [INFO] Model Probability: 0.025896697734317114  Loop: 65000   KeyPoint Top Left Corner (x,y) [1948, 504]
# [INFO] Model Probability: 0.008448284068846158  Loop: 66000   KeyPoint Top Left Corner (x,y) [1852, 512]
# [INFO] Model Probability: 0.004458313029561968  Loop: 67000   KeyPoint Top Left Corner (x,y) [1756, 520]
# [INFO] Model Probability: 0.0062499866707404214  Loop: 68000   KeyPoint Top Left Corner (x,y) [1660, 528]
# [INFO] Model Probability: 0.011133980350802567  Loop: 69000   KeyPoint Top Left Corner (x,y) [1564, 536]
# [INFO] Model Probability: 0.018979217033308755  Loop: 70000   KeyPoint Top Left Corner (x,y) [1468, 544]
# [INFO] Model Probability: 0.021179322957330833  Loop: 71000   KeyPoint Top Left Corner (x,y) [1372, 552]
# [INFO] Model Probability: 0.011360225029739773  Loop: 72000   KeyPoint Top Left Corner (x,y) [1276, 560]
# [INFO] Model Probability: 0.017400211412985526  Loop: 73000   KeyPoint Top Left Corner (x,y) [1180, 568]
# [INFO] Model Probability: 0.0176039963913495  Loop: 74000   KeyPoint Top Left Corner (x,y) [1084, 576]
# [INFO] Model Probability: 0.006234283196965006  Loop: 75000   KeyPoint Top Left Corner (x,y) [988, 584]
# [INFO] Model Probability: 0.019038164545804016  Loop: 76000   KeyPoint Top Left Corner (x,y) [892, 592]
# [INFO] Model Probability: 0.004806650505893571  Loop: 77000   KeyPoint Top Left Corner (x,y) [796, 600]
# [INFO] Model Probability: 0.011535298678307968  Loop: 78000   KeyPoint Top Left Corner (x,y) [700, 608]
# [INFO] Model Probability: 0.01182081634051618  Loop: 79000   KeyPoint Top Left Corner (x,y) [604, 616]
# [INFO] Model Probability: 0.0342738182167339  Loop: 80000   KeyPoint Top Left Corner (x,y) [508, 624]
# [INFO] Model Probability: 0.004829361456612266  Loop: 81000   KeyPoint Top Left Corner (x,y) [412, 632]
# [INFO] Model Probability: 0.004720519221825309  Loop: 82000   KeyPoint Top Left Corner (x,y) [316, 640]
# [INFO] Model Probability: 0.00948675714460559  Loop: 83000   KeyPoint Top Left Corner (x,y) [220, 648]
# [INFO] Model Probability: 0.0032983537817196243  Loop: 84000   KeyPoint Top Left Corner (x,y) [124, 656]
# [INFO] Model Probability: 0.04184498894020934  Loop: 85000   KeyPoint Top Left Corner (x,y) [28, 664]
# [INFO] Model Probability: 0.01617625538010429  Loop: 87000   KeyPoint Top Left Corner (x,y) [1884, 676]
# [INFO] Model Probability: 0.025063917839980316  Loop: 88000   KeyPoint Top Left Corner (x,y) [1788, 684]
# [INFO] Model Probability: 0.00943687785510515  Loop: 89000   KeyPoint Top Left Corner (x,y) [1692, 692]
# [INFO] Model Probability: 0.02288795700819651  Loop: 90000   KeyPoint Top Left Corner (x,y) [1596, 700]
# [INFO] Model Probability: 0.05954757020559639  Loop: 91000   KeyPoint Top Left Corner (x,y) [1500, 708]
# [INFO] Model Probability: 0.030867206235054442  Loop: 92000   KeyPoint Top Left Corner (x,y) [1404, 716]
# [INFO] Model Probability: 0.016593534279834857  Loop: 93000   KeyPoint Top Left Corner (x,y) [1308, 724]
# [INFO] Model Probability: 0.016505238404428003  Loop: 94000   KeyPoint Top Left Corner (x,y) [1212, 732]
# [INFO] Model Probability: 0.02415499481965952  Loop: 95000   KeyPoint Top Left Corner (x,y) [1116, 740]
# [INFO] Model Probability: 0.09345644529953893  Loop: 96000   KeyPoint Top Left Corner (x,y) [1020, 748]
# [INFO] Model Probability: 0.024552771104012452  Loop: 97000   KeyPoint Top Left Corner (x,y) [924, 756]
# [INFO] Model Probability: 0.01844080044464131  Loop: 98000   KeyPoint Top Left Corner (x,y) [828, 764]
# [INFO] Model Probability: 0.005663375484754722  Loop: 99000   KeyPoint Top Left Corner (x,y) [732, 772]
# [INFO] Model Probability: 0.021936839565135854  Loop: 100000   KeyPoint Top Left Corner (x,y) [636, 780]
# [INFO] Model Probability: 0.05200344810596025  Loop: 101000   KeyPoint Top Left Corner (x,y) [540, 788]
# [INFO] Model Probability: 0.00911549400283453  Loop: 102000   KeyPoint Top Left Corner (x,y) [444, 796]
# [INFO] Model Probability: 0.0043485085858466  Loop: 103000   KeyPoint Top Left Corner (x,y) [348, 804]
# [INFO] Model Probability: 0.02419880389024543  Loop: 104000   KeyPoint Top Left Corner (x,y) [252, 812]
# [INFO] Model Probability: 0.01613577688867805  Loop: 105000   KeyPoint Top Left Corner (x,y) [156, 820]
# [INFO] Model Probability: 0.009034200043564082  Loop: 106000   KeyPoint Top Left Corner (x,y) [60, 828]
# [INFO] Model Probability: 0.0035315055015473803  Loop: 108000   KeyPoint Top Left Corner (x,y) [1916, 840]
# [INFO] Model Probability: 0.0022715449712170347  Loop: 109000   KeyPoint Top Left Corner (x,y) [1820, 848]
# [INFO] Model Probability: 0.03932878410877196  Loop: 110000   KeyPoint Top Left Corner (x,y) [1724, 856]
# [INFO] Model Probability: 0.004874429849984462  Loop: 111000   KeyPoint Top Left Corner (x,y) [1628, 864]
# [INFO] Model Probability: 0.031183201815925717  Loop: 112000   KeyPoint Top Left Corner (x,y) [1532, 872]
# [INFO] Model Probability: 0.006510807967282493  Loop: 113000   KeyPoint Top Left Corner (x,y) [1436, 880]
# [INFO] Model Probability: 0.05397388930991457  Loop: 114000   KeyPoint Top Left Corner (x,y) [1340, 888]
# [INFO] Model Probability: 0.009370763906217898  Loop: 115000   KeyPoint Top Left Corner (x,y) [1244, 896]
# [INFO] Model Probability: 0.005348841180670008  Loop: 116000   KeyPoint Top Left Corner (x,y) [1148, 904]
# [INFO] Model Probability: 0.021022880422118317  Loop: 117000   KeyPoint Top Left Corner (x,y) [1052, 912]
# [INFO] Model Probability: 0.002081197546760373  Loop: 118000   KeyPoint Top Left Corner (x,y) [956, 920]
# [INFO] Model Probability: 0.0020505198180134085  Loop: 119000   KeyPoint Top Left Corner (x,y) [860, 928]
# [INFO] Model Probability: 0.003236086400418872  Loop: 120000   KeyPoint Top Left Corner (x,y) [764, 936]
# [INFO] Model Probability: 0.0004516481217543386  Loop: 121000   KeyPoint Top Left Corner (x,y) [668, 944]
# [INFO] Model Probability: 0.002740614585693245  Loop: 122000   KeyPoint Top Left Corner (x,y) [572, 952]
# [INFO] Model Probability: 0.004339827158613364  Loop: 123000   KeyPoint Top Left Corner (x,y) [476, 960]
# [INFO] Model Probability: 0.009852153974711968  Loop: 124000   KeyPoint Top Left Corner (x,y) [380, 968]
# [INFO] Model Probability: 0.010469979139753106  Loop: 125000   KeyPoint Top Left Corner (x,y) [284, 976]
# [INFO] Model Probability: 0.008234753928155815  Loop: 126000   KeyPoint Top Left Corner (x,y) [188, 984]
# [INFO] Model Probability: 0.018438699497965137  Loop: 127000   KeyPoint Top Left Corner (x,y) [92, 992]
# [INFO] Model Probability: 0.0019074881267482624  Loop: 129000   KeyPoint Top Left Corner (x,y) [1948, 1004]
# [INFO] Model Probability: 0.0019488929863181528  Loop: 130000   KeyPoint Top Left Corner (x,y) [1852, 1012]
# [INFO] Model Probability: 0.01283454504159061  Loop: 131000   KeyPoint Top Left Corner (x,y) [1756, 1020]
# [INFO] Model Probability: 0.009733833142727211  Loop: 132000   KeyPoint Top Left Corner (x,y) [1660, 1028]
# [INFO] Model Probability: 0.020671388134327152  Loop: 133000   KeyPoint Top Left Corner (x,y) [1564, 1036]
# [INFO] Model Probability: 0.009126861301109818  Loop: 134000   KeyPoint Top Left Corner (x,y) [1468, 1044]
# [INFO] Model Probability: 0.003974837048832379  Loop: 135000   KeyPoint Top Left Corner (x,y) [1372, 1052]
# [INFO] Model Probability: 0.012265602489540922  Loop: 136000   KeyPoint Top Left Corner (x,y) [1276, 1060]
# [INFO] Model Probability: 0.010321574115114066  Loop: 137000   KeyPoint Top Left Corner (x,y) [1180, 1068]
# [INFO] Model Probability: 0.0017737578535876734  Loop: 138000   KeyPoint Top Left Corner (x,y) [1084, 1076]
# [INFO] Model Probability: 0.008841786739095034  Loop: 139000   KeyPoint Top Left Corner (x,y) [988, 1084]
# [INFO] Model Probability: 0.007692901886196095  Loop: 140000   KeyPoint Top Left Corner (x,y) [892, 1092]
# [INFO] Model Probability: 0.01434855368092209  Loop: 141000   KeyPoint Top Left Corner (x,y) [796, 1100]
# [INFO] Model Probability: 0.004910043105094335  Loop: 142000   KeyPoint Top Left Corner (x,y) [700, 1108]
# [INFO] Model Probability: 0.018980060192468784  Loop: 143000   KeyPoint Top Left Corner (x,y) [604, 1116]
# [INFO] Model Probability: 0.010336885302234814  Loop: 144000   KeyPoint Top Left Corner (x,y) [508, 1124]
# [INFO] Model Probability: 0.003067646629809003  Loop: 145000   KeyPoint Top Left Corner (x,y) [412, 1132]
# [INFO] Model Probability: 0.008183729542356646  Loop: 146000   KeyPoint Top Left Corner (x,y) [316, 1140]
# [INFO] Model Probability: 0.0038530168723970026  Loop: 147000   KeyPoint Top Left Corner (x,y) [220, 1148]
# [INFO] Model Probability: 0.022492078293643438  Loop: 148000   KeyPoint Top Left Corner (x,y) [124, 1156]
# [INFO] Model Probability: 0.0136720454911613  Loop: 149000   KeyPoint Top Left Corner (x,y) [28, 1164]
# [INFO] Model Probability: 0.007382018172838515  Loop: 151000   KeyPoint Top Left Corner (x,y) [1884, 1176]
# [INFO] Model Probability: 0.006852944983619939  Loop: 152000   KeyPoint Top Left Corner (x,y) [1788, 1184]
# [INFO] Model Probability: 0.015541774630345484  Loop: 153000   KeyPoint Top Left Corner (x,y) [1692, 1192]
# [INFO] Model Probability: 0.0008945430538165113  Loop: 154000   KeyPoint Top Left Corner (x,y) [1596, 1200]
# [INFO] Model Probability: 0.08062259658487043  Loop: 155000   KeyPoint Top Left Corner (x,y) [1500, 1208]
# [INFO] Model Probability: 0.009495884308240013  Loop: 156000   KeyPoint Top Left Corner (x,y) [1404, 1216]
# [INFO] Model Probability: 0.0070099236775355315  Loop: 157000   KeyPoint Top Left Corner (x,y) [1308, 1224]
# [INFO] Model Probability: 0.002773666481295161  Loop: 158000   KeyPoint Top Left Corner (x,y) [1212, 1232]
# [INFO] Model Probability: 0.011458553882122845  Loop: 159000   KeyPoint Top Left Corner (x,y) [1116, 1240]
# [INFO] Model Probability: 0.017403743478508638  Loop: 160000   KeyPoint Top Left Corner (x,y) [1020, 1248]
# [INFO] Model Probability: 0.008711695846313655  Loop: 161000   KeyPoint Top Left Corner (x,y) [924, 1256]
# [INFO] Model Probability: 0.024867881164658816  Loop: 162000   KeyPoint Top Left Corner (x,y) [828, 1264]
# [INFO] Model Probability: 0.012341115860575081  Loop: 163000   KeyPoint Top Left Corner (x,y) [732, 1272]
# [INFO] Model Probability: 0.006882583252773776  Loop: 164000   KeyPoint Top Left Corner (x,y) [636, 1280]
# [INFO] Model Probability: 0.0046094407232604865  Loop: 165000   KeyPoint Top Left Corner (x,y) [540, 1288]
# [INFO] Model Probability: 0.019164042805744234  Loop: 166000   KeyPoint Top Left Corner (x,y) [444, 1296]
# [INFO] Model Probability: 0.01245698766043467  Loop: 167000   KeyPoint Top Left Corner (x,y) [348, 1304]
# [INFO] Model Probability: 0.010879318592288648  Loop: 168000   KeyPoint Top Left Corner (x,y) [252, 1312]
# [INFO] Model Probability: 0.004450756950073294  Loop: 169000   KeyPoint Top Left Corner (x,y) [156, 1320]
# [INFO] Model Probability: 0.007039040773627991  Loop: 170000   KeyPoint Top Left Corner (x,y) [60, 1328]
# [INFO] Model Probability: 0.0029922923764374365  Loop: 172000   KeyPoint Top Left Corner (x,y) [1916, 1340]
# [INFO] Model Probability: 0.02417547356862114  Loop: 173000   KeyPoint Top Left Corner (x,y) [1820, 1348]
# [INFO] Model Probability: 0.007762077455834548  Loop: 174000   KeyPoint Top Left Corner (x,y) [1724, 1356]
# [INFO] Model Probability: 0.032826931686410675  Loop: 175000   KeyPoint Top Left Corner (x,y) [1628, 1364]
# [INFO] Model Probability: 0.022655139954875995  Loop: 176000   KeyPoint Top Left Corner (x,y) [1532, 1372]
# [INFO] Model Probability: 0.004920807119789303  Loop: 177000   KeyPoint Top Left Corner (x,y) [1436, 1380]
# [INFO] Model Probability: 0.009994153578877289  Loop: 178000   KeyPoint Top Left Corner (x,y) [1340, 1388]
# [INFO] Model Probability: 0.002898405616297013  Loop: 179000   KeyPoint Top Left Corner (x,y) [1244, 1396]
# [INFO] Model Probability: 0.005923839672630709  Loop: 180000   KeyPoint Top Left Corner (x,y) [1148, 1404]
# [INFO] Model Probability: 0.13929087422704856  Loop: 181000   KeyPoint Top Left Corner (x,y) [1052, 1412]
# [INFO] Model Probability: 0.011016246573479676  Loop: 182000   KeyPoint Top Left Corner (x,y) [956, 1420]
# [INFO] Model Probability: 0.010317262402156179  Loop: 183000   KeyPoint Top Left Corner (x,y) [860, 1428]
# [INFO] Model Probability: 0.01332915468865176  Loop: 184000   KeyPoint Top Left Corner (x,y) [764, 1436]
# [INFO] Model Probability: 0.009367220325035319  Loop: 185000   KeyPoint Top Left Corner (x,y) [668, 1444]
# [INFO] Model Probability: 0.0422365394025028  Loop: 186000   KeyPoint Top Left Corner (x,y) [572, 1452]
# [INFO] Model Probability: 0.009772979214985733  Loop: 187000   KeyPoint Top Left Corner (x,y) [476, 1460]
# [INFO] Model Probability: 0.003086438272747585  Loop: 188000   KeyPoint Top Left Corner (x,y) [380, 1468]
# [INFO] Investigating layer 1 at scale: 1.5
# [INFO] Model Probability: 0.011189962427871163  Loop: 1000   KeyPoint Top Left Corner (x,y) [1260, 8]
# [INFO] Model Probability: 0.00534635191637768  Loop: 2000   KeyPoint Top Left Corner (x,y) [1156, 20]
# [INFO] Model Probability: 0.007203477092654935  Loop: 3000   KeyPoint Top Left Corner (x,y) [1052, 32]
# [INFO] Model Probability: 0.010052780211572796  Loop: 4000   KeyPoint Top Left Corner (x,y) [948, 44]
# [INFO] Model Probability: 0.015353934706285832  Loop: 5000   KeyPoint Top Left Corner (x,y) [844, 56]
# [INFO] Model Probability: 0.022787708618859856  Loop: 6000   KeyPoint Top Left Corner (x,y) [740, 68]
# [INFO] Model Probability: 0.005446875365218989  Loop: 7000   KeyPoint Top Left Corner (x,y) [636, 80]
# [INFO] Model Probability: 0.001408441511055349  Loop: 8000   KeyPoint Top Left Corner (x,y) [532, 92]
# [INFO] Model Probability: 0.001449673619272274  Loop: 9000   KeyPoint Top Left Corner (x,y) [428, 104]
# [INFO] Model Probability: 0.013641571271095377  Loop: 10000   KeyPoint Top Left Corner (x,y) [324, 116]
# [INFO] Model Probability: 0.013855477880812258  Loop: 11000   KeyPoint Top Left Corner (x,y) [220, 128]
# [INFO] Model Probability: 0.010321383918815335  Loop: 12000   KeyPoint Top Left Corner (x,y) [116, 140]
# [INFO] Model Probability: 0.013486824358161098  Loop: 13000   KeyPoint Top Left Corner (x,y) [12, 152]
# [INFO] Model Probability: 0.02115103439401553  Loop: 14000   KeyPoint Top Left Corner (x,y) [1276, 160]
# [INFO] Model Probability: 0.007111626346001339  Loop: 15000   KeyPoint Top Left Corner (x,y) [1172, 172]
# [INFO] Model Probability: 0.00907538910771851  Loop: 16000   KeyPoint Top Left Corner (x,y) [1068, 184]
# [INFO] Model Probability: 0.0034191049831539698  Loop: 17000   KeyPoint Top Left Corner (x,y) [964, 196]
# [INFO] Model Probability: 0.0030037940044771094  Loop: 18000   KeyPoint Top Left Corner (x,y) [860, 208]
# [INFO] Model Probability: 0.01168794788641304  Loop: 19000   KeyPoint Top Left Corner (x,y) [756, 220]
# [INFO] Model Probability: 0.0012999504864590944  Loop: 20000   KeyPoint Top Left Corner (x,y) [652, 232]
# [INFO] Model Probability: 0.0035131264235291055  Loop: 21000   KeyPoint Top Left Corner (x,y) [548, 244]
# [INFO] Model Probability: 0.007665988101284696  Loop: 22000   KeyPoint Top Left Corner (x,y) [444, 256]
# [INFO] Model Probability: 0.020564411243225902  Loop: 23000   KeyPoint Top Left Corner (x,y) [340, 268]
# [INFO] Model Probability: 0.010565805803649013  Loop: 24000   KeyPoint Top Left Corner (x,y) [236, 280]
# [INFO] Model Probability: 0.007474395393281078  Loop: 25000   KeyPoint Top Left Corner (x,y) [132, 292]
# [INFO] Model Probability: 0.01810546683453497  Loop: 26000   KeyPoint Top Left Corner (x,y) [28, 304]
# [INFO] Model Probability: 0.004512849303406938  Loop: 28000   KeyPoint Top Left Corner (x,y) [1188, 324]
# [INFO] Model Probability: 0.0042706766147540196  Loop: 29000   KeyPoint Top Left Corner (x,y) [1084, 336]
# [INFO] Model Probability: 0.014688680065997448  Loop: 30000   KeyPoint Top Left Corner (x,y) [980, 348]
# [INFO] Model Probability: 0.01120469642705162  Loop: 31000   KeyPoint Top Left Corner (x,y) [876, 360]
# [INFO] Model Probability: 0.006599396130547049  Loop: 32000   KeyPoint Top Left Corner (x,y) [772, 372]
# [INFO] Model Probability: 0.006060432001556704  Loop: 33000   KeyPoint Top Left Corner (x,y) [668, 384]
# [INFO] Model Probability: 0.004602843918543832  Loop: 34000   KeyPoint Top Left Corner (x,y) [564, 396]
# [INFO] Model Probability: 0.013709422114261611  Loop: 35000   KeyPoint Top Left Corner (x,y) [460, 408]
# [INFO] Model Probability: 0.008177387542894016  Loop: 36000   KeyPoint Top Left Corner (x,y) [356, 420]
# [INFO] Model Probability: 0.01059203220373987  Loop: 37000   KeyPoint Top Left Corner (x,y) [252, 432]
# [INFO] Model Probability: 0.0038345662955437615  Loop: 38000   KeyPoint Top Left Corner (x,y) [148, 444]
# [INFO] Model Probability: 0.005883193037383165  Loop: 39000   KeyPoint Top Left Corner (x,y) [44, 456]
# [INFO] Model Probability: 0.004335370243674749  Loop: 41000   KeyPoint Top Left Corner (x,y) [1204, 476]
# [INFO] Model Probability: 0.00941368609864346  Loop: 42000   KeyPoint Top Left Corner (x,y) [1100, 488]
# [INFO] Model Probability: 0.024240876194182227  Loop: 43000   KeyPoint Top Left Corner (x,y) [996, 500]
# [INFO] Model Probability: 0.011656696329931064  Loop: 44000   KeyPoint Top Left Corner (x,y) [892, 512]
# [INFO] Model Probability: 0.0024554067232669934  Loop: 45000   KeyPoint Top Left Corner (x,y) [788, 524]
# [INFO] Model Probability: 0.01352720384871798  Loop: 46000   KeyPoint Top Left Corner (x,y) [684, 536]
# [INFO] Model Probability: 0.0043324796733614  Loop: 47000   KeyPoint Top Left Corner (x,y) [580, 548]
# [INFO] Model Probability: 0.011923161024185879  Loop: 48000   KeyPoint Top Left Corner (x,y) [476, 560]
# [INFO] Model Probability: 0.009619142470126503  Loop: 49000   KeyPoint Top Left Corner (x,y) [372, 572]
# [INFO] Model Probability: 0.007851312597874893  Loop: 50000   KeyPoint Top Left Corner (x,y) [268, 584]
# [INFO] Model Probability: 0.012102695983502812  Loop: 51000   KeyPoint Top Left Corner (x,y) [164, 596]
# [INFO] Model Probability: 0.008482334395083571  Loop: 52000   KeyPoint Top Left Corner (x,y) [60, 608]
# [INFO] Model Probability: 0.058711961187375206  Loop: 54000   KeyPoint Top Left Corner (x,y) [1220, 628]
# [INFO] Model Probability: 0.005399463313522308  Loop: 55000   KeyPoint Top Left Corner (x,y) [1116, 640]
# [INFO] Model Probability: 0.0028056819990059044  Loop: 56000   KeyPoint Top Left Corner (x,y) [1012, 652]
# [INFO] Model Probability: 0.03027931600018633  Loop: 57000   KeyPoint Top Left Corner (x,y) [908, 664]
# [INFO] Model Probability: 0.00766015369958758  Loop: 58000   KeyPoint Top Left Corner (x,y) [804, 676]
# [INFO] Model Probability: 0.003931935807107756  Loop: 59000   KeyPoint Top Left Corner (x,y) [700, 688]
# [INFO] Model Probability: 0.006061975822449984  Loop: 60000   KeyPoint Top Left Corner (x,y) [596, 700]
# [INFO] Model Probability: 0.00832601985277533  Loop: 61000   KeyPoint Top Left Corner (x,y) [492, 712]
# [INFO] Model Probability: 0.011947449029532499  Loop: 62000   KeyPoint Top Left Corner (x,y) [388, 724]
# [INFO] Model Probability: 0.0023114542001179826  Loop: 63000   KeyPoint Top Left Corner (x,y) [284, 736]
# [INFO] Model Probability: 0.01062444516313362  Loop: 64000   KeyPoint Top Left Corner (x,y) [180, 748]
# [INFO] Model Probability: 0.01105288696408559  Loop: 65000   KeyPoint Top Left Corner (x,y) [76, 760]
# [INFO] Model Probability: 0.0054787361227119835  Loop: 67000   KeyPoint Top Left Corner (x,y) [1236, 780]
# [INFO] Model Probability: 0.017914948296339495  Loop: 68000   KeyPoint Top Left Corner (x,y) [1132, 792]
# [INFO] Model Probability: 0.002797375236624893  Loop: 69000   KeyPoint Top Left Corner (x,y) [1028, 804]
# [INFO] Model Probability: 0.004727786767541016  Loop: 70000   KeyPoint Top Left Corner (x,y) [924, 816]
# [INFO] Model Probability: 0.014636914191783949  Loop: 71000   KeyPoint Top Left Corner (x,y) [820, 828]
# [INFO] Model Probability: 0.008234764960884274  Loop: 72000   KeyPoint Top Left Corner (x,y) [716, 840]
# [INFO] Model Probability: 0.007855498000618796  Loop: 73000   KeyPoint Top Left Corner (x,y) [612, 852]
# [INFO] Model Probability: 0.003850313998704809  Loop: 74000   KeyPoint Top Left Corner (x,y) [508, 864]
# [INFO] Model Probability: 0.007902074310814156  Loop: 75000   KeyPoint Top Left Corner (x,y) [404, 876]
# [INFO] Model Probability: 0.007402388787904053  Loop: 76000   KeyPoint Top Left Corner (x,y) [300, 888]
# [INFO] Model Probability: 0.0208680527918532  Loop: 77000   KeyPoint Top Left Corner (x,y) [196, 900]
# [INFO] Model Probability: 0.016087223448116143  Loop: 78000   KeyPoint Top Left Corner (x,y) [92, 912]
# [INFO] Model Probability: 0.0025834382385924066  Loop: 80000   KeyPoint Top Left Corner (x,y) [1252, 932]
# [INFO] Model Probability: 0.01944079960205566  Loop: 81000   KeyPoint Top Left Corner (x,y) [1148, 944]
# [INFO] Model Probability: 0.0017943056125135513  Loop: 82000   KeyPoint Top Left Corner (x,y) [1044, 956]
# [INFO] Investigating layer 2 at scale: 2.2521994134897363
# [INFO] Model Probability: 0.005292605081021027  Loop: 1000   KeyPoint Top Left Corner (x,y) [348, 16]
# [INFO] Model Probability: 0.010830201762084062  Loop: 2000   KeyPoint Top Left Corner (x,y) [700, 32]
# [INFO] Model Probability: 0.013572978379673778  Loop: 3000   KeyPoint Top Left Corner (x,y) [140, 52]
# [INFO] Model Probability: 0.009671081578290138  Loop: 4000   KeyPoint Top Left Corner (x,y) [492, 68]
# [INFO] Model Probability: 0.010781833029259644  Loop: 6000   KeyPoint Top Left Corner (x,y) [284, 104]
# [INFO] Model Probability: 0.002902570592327505  Loop: 7000   KeyPoint Top Left Corner (x,y) [636, 120]
# [INFO] Model Probability: 0.004766083092201024  Loop: 8000   KeyPoint Top Left Corner (x,y) [76, 140]
# [INFO] Model Probability: 0.011562942041204295  Loop: 9000   KeyPoint Top Left Corner (x,y) [428, 156]
# [INFO] Model Probability: 0.010058376519675  Loop: 10000   KeyPoint Top Left Corner (x,y) [780, 172]
# [INFO] Model Probability: 0.007772446853124301  Loop: 11000   KeyPoint Top Left Corner (x,y) [220, 192]
# [INFO] Model Probability: 0.0020655393906182434  Loop: 12000   KeyPoint Top Left Corner (x,y) [572, 208]
# [INFO] Model Probability: 0.02292806730389501  Loop: 13000   KeyPoint Top Left Corner (x,y) [12, 228]
# [INFO] Model Probability: 0.005326876372234396  Loop: 14000   KeyPoint Top Left Corner (x,y) [364, 244]
# [INFO] Model Probability: 0.011248129085847896  Loop: 15000   KeyPoint Top Left Corner (x,y) [716, 260]
# [INFO] Model Probability: 0.01233173029131902  Loop: 16000   KeyPoint Top Left Corner (x,y) [156, 280]
# [INFO] Model Probability: 0.0030452952863556774  Loop: 17000   KeyPoint Top Left Corner (x,y) [508, 296]
# [INFO] Model Probability: 0.005085975613719415  Loop: 19000   KeyPoint Top Left Corner (x,y) [300, 332]
# [INFO] Model Probability: 0.007120175305465725  Loop: 20000   KeyPoint Top Left Corner (x,y) [652, 348]
# [INFO] Model Probability: 0.016899699330930183  Loop: 21000   KeyPoint Top Left Corner (x,y) [92, 368]
# [INFO] Model Probability: 0.013700440883697403  Loop: 22000   KeyPoint Top Left Corner (x,y) [444, 384]
# [INFO] Model Probability: 0.023258653172310805  Loop: 23000   KeyPoint Top Left Corner (x,y) [796, 400]
# [INFO] Model Probability: 0.01490673651535341  Loop: 24000   KeyPoint Top Left Corner (x,y) [236, 420]
# [INFO] Model Probability: 0.01487067917382264  Loop: 25000   KeyPoint Top Left Corner (x,y) [588, 436]
# [INFO] Model Probability: 0.0038238772330053865  Loop: 26000   KeyPoint Top Left Corner (x,y) [28, 456]
# [INFO] Model Probability: 0.014259021179014267  Loop: 27000   KeyPoint Top Left Corner (x,y) [380, 472]
# [INFO] Model Probability: 0.001931478440317033  Loop: 28000   KeyPoint Top Left Corner (x,y) [732, 488]
# [INFO] Model Probability: 0.0020155636492737113  Loop: 29000   KeyPoint Top Left Corner (x,y) [172, 508]
# [INFO] Model Probability: 0.0018823829247108426  Loop: 30000   KeyPoint Top Left Corner (x,y) [524, 524]
# [INFO] Model Probability: 0.005504149931494952  Loop: 32000   KeyPoint Top Left Corner (x,y) [316, 560]
# [INFO] Model Probability: 0.014108782411072733  Loop: 33000   KeyPoint Top Left Corner (x,y) [668, 576]
# [INFO] Model Probability: 0.016508547010243756  Loop: 34000   KeyPoint Top Left Corner (x,y) [108, 596]
# [INFO] Model Probability: 0.009822431726835596  Loop: 35000   KeyPoint Top Left Corner (x,y) [460, 612]
# [INFO] Investigating layer 3 at scale: 3.383259911894273
# [INFO] Model Probability: 0.008165727297504548  Loop: 1000   KeyPoint Top Left Corner (x,y) [348, 24]
# [INFO] Model Probability: 0.010296469081199442  Loop: 2000   KeyPoint Top Left Corner (x,y) [92, 52]
# [INFO] Model Probability: 0.003595179683962044  Loop: 3000   KeyPoint Top Left Corner (x,y) [444, 76]
# [INFO] Model Probability: 0.010771900684211366  Loop: 4000   KeyPoint Top Left Corner (x,y) [188, 104]
# [INFO] Model Probability: 0.010852634910916988  Loop: 6000   KeyPoint Top Left Corner (x,y) [284, 156]
# [INFO] Model Probability: 0.006297267088025093  Loop: 7000   KeyPoint Top Left Corner (x,y) [28, 184]
# [INFO] Model Probability: 0.013860796049507084  Loop: 8000   KeyPoint Top Left Corner (x,y) [380, 208]
# [INFO] Model Probability: 0.0186662635061681  Loop: 9000   KeyPoint Top Left Corner (x,y) [124, 236]
# [INFO] Model Probability: 0.004607251573439904  Loop: 10000   KeyPoint Top Left Corner (x,y) [476, 260]
# [INFO] Model Probability: 0.0049937513774737045  Loop: 11000   KeyPoint Top Left Corner (x,y) [220, 288]
# [INFO] Model Probability: 0.0028066283139931156  Loop: 13000   KeyPoint Top Left Corner (x,y) [316, 340]
# [INFO] Model Probability: 0.006239446404465167  Loop: 14000   KeyPoint Top Left Corner (x,y) [60, 368]
# [INFO] Investigating layer 4 at scale: 5.086092715231788
# [INFO] Model Probability: 0.020586851464779284  Loop: 3000   KeyPoint Top Left Corner (x,y) [280, 116]
# [INFO] Model Probability: 0.0053763222267194065  Loop: 4000   KeyPoint Top Left Corner (x,y) [240, 156]
# [INFO] Model Probability: 0.0033111246786820298  Loop: 5000   KeyPoint Top Left Corner (x,y) [200, 196]
# [INFO] Model Probability: 0.02016048437377046  Loop: 6000   KeyPoint Top Left Corner (x,y) [160, 236]
# [INFO] Investigating layer 5 at scale: 7.641791044776119
# [INFO] Model Probability: 0.003792135166413771  Loop: 2000   KeyPoint Top Left Corner (x,y) [108, 116]
# [INFO] Investigating layer 6 at scale: 11.462686567164178
# [INFO] Investigating layer 7 at scale: 17.258426966292134
# [INFO] 39 boxes were found with a probablility > 0.51
# [INFO] Scanning file: M:\DataSets\Caltech256\256_ObjectCategories\013.birdbath\013_0071.jpg
# [INFO] Investigating layer 0 at scale: 1.0
# [INFO] Model Probability: 0.0011877402341272157  Loop: 1000   KeyPoint Top Left Corner (x,y) [36, 44]
# [INFO] Model Probability: 0.08474822532742672  Loop: 2000   KeyPoint Top Left Corner (x,y) [76, 88]
# [INFO] Model Probability: 0.0004653574750966007  Loop: 3000   KeyPoint Top Left Corner (x,y) [116, 132]
# [INFO] Model Probability: 0.006377283707520282  Loop: 4000   KeyPoint Top Left Corner (x,y) [156, 176]
# [INFO] Model Probability: 0.010019653856495784  Loop: 5000   KeyPoint Top Left Corner (x,y) [196, 220]
# [INFO] Model Probability: 0.010414519938935517  Loop: 6000   KeyPoint Top Left Corner (x,y) [236, 264]
# [INFO] Investigating layer 1 at scale: 1.5
# [INFO] Model Probability: 0.012570006305947323  Loop: 2000   KeyPoint Top Left Corner (x,y) [76, 132]
# [INFO] Investigating layer 2 at scale: 2.25
# [INFO] Investigating layer 3 at scale: 3.38255033557047
# [INFO] 25 boxes were found with a probablility > 0.51
# [INFO] Scanning file: M:\DataSets\Caltech256\256_ObjectCategories\013.birdbath\013_0012.jpg
# [INFO] Investigating layer 0 at scale: 1.0
# [INFO] Model Probability: 0.035096771510642874  Loop: 1000   KeyPoint Top Left Corner (x,y) [76, 28]
# [INFO] Model Probability: 0.3652166514961274  Loop: 2000   KeyPoint Top Left Corner (x,y) [156, 56]
# [INFO] Model Probability: 0.0007367710119146253  Loop: 3000   KeyPoint Top Left Corner (x,y) [236, 84]
# [INFO] Model Probability: 0.05740094221077587  Loop: 4000   KeyPoint Top Left Corner (x,y) [316, 112]
# [INFO] Model Probability: 0.007298991745480121  Loop: 5000   KeyPoint Top Left Corner (x,y) [396, 140]
# [INFO] Model Probability: 0.008229589551049793  Loop: 8000   KeyPoint Top Left Corner (x,y) [76, 228]
# [INFO] Model Probability: 0.014400690077638272  Loop: 9000   KeyPoint Top Left Corner (x,y) [156, 256]
# [INFO] Model Probability: 0.14490528291613586  Loop: 10000   KeyPoint Top Left Corner (x,y) [236, 284]
# [INFO] Model Probability: 0.013626863791021309  Loop: 11000   KeyPoint Top Left Corner (x,y) [316, 312]
# [INFO] Model Probability: 0.01338119879057924  Loop: 12000   KeyPoint Top Left Corner (x,y) [396, 340]
# [INFO] Model Probability: 0.008286826122861008  Loop: 15000   KeyPoint Top Left Corner (x,y) [76, 428]
# [INFO] Model Probability: 0.014042644487763071  Loop: 16000   KeyPoint Top Left Corner (x,y) [156, 456]
# [INFO] Model Probability: 0.043935990850668336  Loop: 17000   KeyPoint Top Left Corner (x,y) [236, 484]
# [INFO] Model Probability: 0.05399315530651145  Loop: 18000   KeyPoint Top Left Corner (x,y) [316, 512]
# [INFO] Model Probability: 0.022331626548093772  Loop: 19000   KeyPoint Top Left Corner (x,y) [396, 540]
# [INFO] Model Probability: 0.012313567011757197  Loop: 22000   KeyPoint Top Left Corner (x,y) [76, 628]
# [INFO] Model Probability: 0.05335898469913146  Loop: 23000   KeyPoint Top Left Corner (x,y) [156, 656]
# [INFO] Model Probability: 0.03377143988085539  Loop: 24000   KeyPoint Top Left Corner (x,y) [236, 684]
# [INFO] Model Probability: 0.24605844916909383  Loop: 25000   KeyPoint Top Left Corner (x,y) [316, 712]
# [INFO] Investigating layer 1 at scale: 1.5009380863039399
# [INFO] Model Probability: 0.003118928235967887  Loop: 1000   KeyPoint Top Left Corner (x,y) [276, 40]
# [INFO] Model Probability: 0.01372095565567351  Loop: 2000   KeyPoint Top Left Corner (x,y) [184, 84]
# [INFO] Model Probability: 0.009700258118744469  Loop: 3000   KeyPoint Top Left Corner (x,y) [92, 128]
# [INFO] Model Probability: 0.007730197844549757  Loop: 4000   KeyPoint Top Left Corner (x,y) [0, 172]
# [INFO] Model Probability: 0.00860215058091493  Loop: 5000   KeyPoint Top Left Corner (x,y) [280, 212]
# [INFO] Model Probability: 0.06173460484033825  Loop: 6000   KeyPoint Top Left Corner (x,y) [188, 256]
# [INFO] Model Probability: 0.015292290722750705  Loop: 7000   KeyPoint Top Left Corner (x,y) [96, 300]
# [INFO] Model Probability: 0.022857686922454493  Loop: 8000   KeyPoint Top Left Corner (x,y) [4, 344]
# [INFO] Model Probability: 0.009802524386825382  Loop: 9000   KeyPoint Top Left Corner (x,y) [284, 384]
# [INFO] Model Probability: 0.04984891916515879  Loop: 10000   KeyPoint Top Left Corner (x,y) [192, 428]
# [INFO] Investigating layer 2 at scale: 2.2535211267605635
# [INFO] Model Probability: 0.004254390399640785  Loop: 1000   KeyPoint Top Left Corner (x,y) [28, 64]
# [INFO] Model Probability: 0.10880542594268837  Loop: 2000   KeyPoint Top Left Corner (x,y) [60, 128]
# [INFO] Model Probability: 0.018459422614692546  Loop: 3000   KeyPoint Top Left Corner (x,y) [92, 192]
# [INFO] Model Probability: 0.01248840991648751  Loop: 4000   KeyPoint Top Left Corner (x,y) [124, 256]
# [INFO] Investigating layer 3 at scale: 3.389830508474576
# [INFO] Investigating layer 4 at scale: 5.095541401273885
# [INFO] 310 boxes were found with a probablility > 0.51
# [INFO] Scanning file: M:\DataSets\Caltech256\256_ObjectCategories\013.birdbath\013_0006.jpg
# [INFO] Investigating layer 0 at scale: 1.0
# [INFO] Model Probability: 0.009916300172680833  Loop: 1000   KeyPoint Top Left Corner (x,y) [76, 20]
# [INFO] Model Probability: 0.06725600462959098  Loop: 2000   KeyPoint Top Left Corner (x,y) [156, 40]
# [INFO] Model Probability: 0.014160372330634292  Loop: 3000   KeyPoint Top Left Corner (x,y) [236, 60]
# [INFO] Model Probability: 0.01287212124035848  Loop: 4000   KeyPoint Top Left Corner (x,y) [316, 80]
# [INFO] Model Probability: 0.015130623289272366  Loop: 5000   KeyPoint Top Left Corner (x,y) [396, 100]
# [INFO] Model Probability: 0.07585095197854987  Loop: 6000   KeyPoint Top Left Corner (x,y) [476, 120]
# [INFO] Model Probability: 0.01782018990981556  Loop: 7000   KeyPoint Top Left Corner (x,y) [556, 140]
# [INFO] Model Probability: 0.00511591726613101  Loop: 8000   KeyPoint Top Left Corner (x,y) [636, 160]
# [INFO] Model Probability: 0.022772099457829167  Loop: 10000   KeyPoint Top Left Corner (x,y) [12, 204]
# [INFO] Model Probability: 0.002498301614475046  Loop: 11000   KeyPoint Top Left Corner (x,y) [92, 224]
# [INFO] Model Probability: 0.01216497632827308  Loop: 12000   KeyPoint Top Left Corner (x,y) [172, 244]
# [INFO] Model Probability: 0.019672776199253093  Loop: 13000   KeyPoint Top Left Corner (x,y) [252, 264]
# [INFO] Model Probability: 0.03202106535819674  Loop: 14000   KeyPoint Top Left Corner (x,y) [332, 284]
# [INFO] Model Probability: 0.004764713166871043  Loop: 15000   KeyPoint Top Left Corner (x,y) [412, 304]
# [INFO] Model Probability: 0.0035695508197397465  Loop: 16000   KeyPoint Top Left Corner (x,y) [492, 324]
# [INFO] Model Probability: 0.0674243212652157  Loop: 17000   KeyPoint Top Left Corner (x,y) [572, 344]
# [INFO] Model Probability: 0.0728288008855729  Loop: 18000   KeyPoint Top Left Corner (x,y) [652, 364]
# [INFO] Model Probability: 0.012818142752644465  Loop: 20000   KeyPoint Top Left Corner (x,y) [28, 408]
# [INFO] Model Probability: 0.010810940806340829  Loop: 21000   KeyPoint Top Left Corner (x,y) [108, 428]
# [INFO] Model Probability: 0.1204450172427245  Loop: 22000   KeyPoint Top Left Corner (x,y) [188, 448]
# [INFO] Model Probability: 0.004517934977057772  Loop: 23000   KeyPoint Top Left Corner (x,y) [268, 468]
# [INFO] Model Probability: 0.012755963466557173  Loop: 24000   KeyPoint Top Left Corner (x,y) [348, 488]
# [INFO] Model Probability: 0.03459721575319561  Loop: 25000   KeyPoint Top Left Corner (x,y) [428, 508]
# [INFO] Model Probability: 0.0039035793725459796  Loop: 26000   KeyPoint Top Left Corner (x,y) [508, 528]
# [INFO] Model Probability: 0.006944609293884843  Loop: 27000   KeyPoint Top Left Corner (x,y) [588, 548]
# [INFO] Model Probability: 0.0031977075196907177  Loop: 28000   KeyPoint Top Left Corner (x,y) [668, 568]
# [INFO] Model Probability: 0.0038382772002436474  Loop: 30000   KeyPoint Top Left Corner (x,y) [44, 612]
# [INFO] Model Probability: 0.3225421279600372  Loop: 31000   KeyPoint Top Left Corner (x,y) [124, 632]
# [INFO] Model Probability: 0.023597909716679202  Loop: 32000   KeyPoint Top Left Corner (x,y) [204, 652]
# [INFO] Model Probability: 0.0029988234724838644  Loop: 33000   KeyPoint Top Left Corner (x,y) [284, 672]
# [INFO] Model Probability: 0.05539577939846245  Loop: 34000   KeyPoint Top Left Corner (x,y) [364, 692]
# [INFO] Model Probability: 0.00283781836436243  Loop: 35000   KeyPoint Top Left Corner (x,y) [444, 712]
# [INFO] Model Probability: 0.006769739893644523  Loop: 36000   KeyPoint Top Left Corner (x,y) [524, 732]
# [INFO] Model Probability: 0.02319213367340666  Loop: 37000   KeyPoint Top Left Corner (x,y) [604, 752]
# [INFO] Model Probability: 0.014982779436783555  Loop: 38000   KeyPoint Top Left Corner (x,y) [684, 772]
# [INFO] Model Probability: 0.002980924578704103  Loop: 40000   KeyPoint Top Left Corner (x,y) [60, 816]
# [INFO] Model Probability: 0.006202663846543048  Loop: 41000   KeyPoint Top Left Corner (x,y) [140, 836]
# [INFO] Model Probability: 0.0090453569806824  Loop: 42000   KeyPoint Top Left Corner (x,y) [220, 856]
# [INFO] Model Probability: 0.009505588652044794  Loop: 43000   KeyPoint Top Left Corner (x,y) [300, 876]
# [INFO] Investigating layer 1 at scale: 1.501577287066246
# [INFO] Model Probability: 0.0070329517116909145  Loop: 1000   KeyPoint Top Left Corner (x,y) [328, 28]
# [INFO] Model Probability: 0.004587154139734151  Loop: 2000   KeyPoint Top Left Corner (x,y) [136, 60]
# [INFO] Model Probability: 0.060454325376818725  Loop: 4000   KeyPoint Top Left Corner (x,y) [276, 120]
# [INFO] Model Probability: 0.012075169033174623  Loop: 5000   KeyPoint Top Left Corner (x,y) [84, 152]
# [INFO] Model Probability: 0.3984403904293521  Loop: 6000   KeyPoint Top Left Corner (x,y) [416, 180]
# [INFO] Model Probability: 0.005951880853167029  Loop: 7000   KeyPoint Top Left Corner (x,y) [224, 212]
# [INFO] Model Probability: 0.09337945448865026  Loop: 8000   KeyPoint Top Left Corner (x,y) [32, 244]
# [INFO] Model Probability: 0.41470053253506434  Loop: 9000   KeyPoint Top Left Corner (x,y) [364, 272]
# [INFO] Model Probability: 0.0022383833002864156  Loop: 10000   KeyPoint Top Left Corner (x,y) [172, 304]
# [INFO] Model Probability: 0.09497850477053878  Loop: 12000   KeyPoint Top Left Corner (x,y) [312, 364]
# [INFO] Model Probability: 0.10092732788034678  Loop: 13000   KeyPoint Top Left Corner (x,y) [120, 396]
# [INFO] Model Probability: 0.0030979427778975843  Loop: 15000   KeyPoint Top Left Corner (x,y) [260, 456]
# [INFO] Model Probability: 0.004565575710726356  Loop: 16000   KeyPoint Top Left Corner (x,y) [68, 488]
# [INFO] Model Probability: 0.03548844856883842  Loop: 17000   KeyPoint Top Left Corner (x,y) [400, 516]
# [INFO] Model Probability: 0.001073688571691788  Loop: 18000   KeyPoint Top Left Corner (x,y) [208, 548]
# [INFO] Investigating layer 2 at scale: 2.255924170616114
# [INFO] Model Probability: 0.06369990625962511  Loop: 1000   KeyPoint Top Left Corner (x,y) [168, 44]
# [INFO] Model Probability: 0.006287226570177543  Loop: 3000   KeyPoint Top Left Corner (x,y) [164, 136]
# [INFO] Model Probability: 0.006759994534800124  Loop: 5000   KeyPoint Top Left Corner (x,y) [160, 228]
# [INFO] Model Probability: 0.08379116600005385  Loop: 7000   KeyPoint Top Left Corner (x,y) [156, 320]
# [INFO] Investigating layer 3 at scale: 3.3879003558718863
# [INFO] Model Probability: 0.05879487079512524  Loop: 1000   KeyPoint Top Left Corner (x,y) [52, 68]
# [INFO] Model Probability: 0.0441602408351859  Loop: 2000   KeyPoint Top Left Corner (x,y) [108, 136]
# [INFO] Investigating layer 4 at scale: 5.090909090909091
# [INFO] Investigating layer 5 at scale: 7.67741935483871
# [INFO] 915 boxes were found with a probablility > 0.51
# [INFO] Scanning file: M:\DataSets\Caltech256\256_ObjectCategories\013.birdbath\013_0084.jpg
# [INFO] Investigating layer 0 at scale: 1.0
# [INFO] Model Probability: 0.0056019114228444975  Loop: 3000   KeyPoint Top Left Corner (x,y) [152, 188]
# [INFO] Model Probability: 0.10430915479711145  Loop: 4000   KeyPoint Top Left Corner (x,y) [120, 252]
# [INFO] Investigating layer 1 at scale: 1.5043478260869565
# [INFO] Investigating layer 2 at scale: 2.261437908496732
# [INFO] 54 boxes were found with a probablility > 0.51
# [INFO] Scanning file: M:\DataSets\Caltech256\256_ObjectCategories\013.birdbath\013_0028.jpg
# [INFO] Investigating layer 0 at scale: 1.0
# [INFO] Model Probability: 0.005855243709382485  Loop: 1000   KeyPoint Top Left Corner (x,y) [156, 24]
# [INFO] Model Probability: 0.24482740587392293  Loop: 2000   KeyPoint Top Left Corner (x,y) [316, 48]
# [INFO] Model Probability: 0.03467734693165907  Loop: 3000   KeyPoint Top Left Corner (x,y) [476, 72]
# [INFO] Model Probability: 0.005855243709382485  Loop: 5000   KeyPoint Top Left Corner (x,y) [156, 124]
# [INFO] Model Probability: 0.8032648072226851  Loop: 6000   KeyPoint Top Left Corner (x,y) [316, 148]
# [INFO] Model Probability: 0.004169552612202345  Loop: 7000   KeyPoint Top Left Corner (x,y) [476, 172]
# [INFO] Model Probability: 0.005855243709382485  Loop: 9000   KeyPoint Top Left Corner (x,y) [156, 224]
# [INFO] Model Probability: 0.0583520383790149  Loop: 10000   KeyPoint Top Left Corner (x,y) [316, 248]
# [INFO] Model Probability: 0.31239915853338757  Loop: 11000   KeyPoint Top Left Corner (x,y) [476, 272]
# [INFO] Model Probability: 0.005855243709382485  Loop: 13000   KeyPoint Top Left Corner (x,y) [156, 324]
# [INFO] Model Probability: 0.5134564963895066  Loop: 14000   KeyPoint Top Left Corner (x,y) [316, 348]
# [INFO] Model Probability: 0.008106966966718754  Loop: 15000   KeyPoint Top Left Corner (x,y) [476, 372]
# [INFO] Investigating layer 1 at scale: 1.5
# [INFO] Model Probability: 0.013738418475337808  Loop: 1000   KeyPoint Top Left Corner (x,y) [144, 36]
# [INFO] Model Probability: 0.7020385876067629  Loop: 2000   KeyPoint Top Left Corner (x,y) [292, 72]
# [INFO] Model Probability: 0.022866552737348653  Loop: 3000   KeyPoint Top Left Corner (x,y) [12, 112]
# [INFO] Model Probability: 0.0067730652149976065  Loop: 4000   KeyPoint Top Left Corner (x,y) [160, 148]
# [INFO] Model Probability: 0.3109070956430364  Loop: 5000   KeyPoint Top Left Corner (x,y) [308, 184]
# [INFO] Model Probability: 0.006019854349162172  Loop: 6000   KeyPoint Top Left Corner (x,y) [28, 224]
# [INFO] Investigating layer 2 at scale: 2.2535211267605635
# [INFO] Model Probability: 0.005855243709382485  Loop: 1000   KeyPoint Top Left Corner (x,y) [20, 56]
# [INFO] Model Probability: 0.008158303285242006  Loop: 2000   KeyPoint Top Left Corner (x,y) [44, 112]
# [INFO] Investigating layer 3 at scale: 3.380281690140845
# [INFO] Investigating layer 4 at scale: 5.1063829787234045
# [INFO] 2754 boxes were found with a probablility > 0.51
# [INFO] Scanning file: M:\DataSets\Caltech256\256_ObjectCategories\013.birdbath\013_0005.jpg
# [INFO] Investigating layer 0 at scale: 1.0
# [INFO] Model Probability: 0.005855243709382485  Loop: 1000   KeyPoint Top Left Corner (x,y) [108, 24]
# [INFO] Model Probability: 0.008751135420771631  Loop: 2000   KeyPoint Top Left Corner (x,y) [220, 48]
# [INFO] Model Probability: 0.000716129310538757  Loop: 3000   KeyPoint Top Left Corner (x,y) [332, 72]
# [INFO] Model Probability: 0.005855243709382485  Loop: 4000   KeyPoint Top Left Corner (x,y) [444, 96]
# [INFO] Model Probability: 0.006229246711444503  Loop: 5000   KeyPoint Top Left Corner (x,y) [556, 120]
# [INFO] Model Probability: 0.036862248921490134  Loop: 6000   KeyPoint Top Left Corner (x,y) [20, 148]
# [INFO] Model Probability: 0.01865269927041961  Loop: 7000   KeyPoint Top Left Corner (x,y) [132, 172]
# [INFO] Model Probability: 0.0017618498742877713  Loop: 8000   KeyPoint Top Left Corner (x,y) [244, 196]
# [INFO] Model Probability: 0.007855625807732707  Loop: 9000   KeyPoint Top Left Corner (x,y) [356, 220]
# [INFO] Model Probability: 0.010274506906875598  Loop: 10000   KeyPoint Top Left Corner (x,y) [468, 244]
# [INFO] Model Probability: 0.024075492505666447  Loop: 12000   KeyPoint Top Left Corner (x,y) [44, 296]
# [INFO] Model Probability: 0.01716888319847254  Loop: 13000   KeyPoint Top Left Corner (x,y) [156, 320]
# [INFO] Model Probability: 0.05084630017639432  Loop: 14000   KeyPoint Top Left Corner (x,y) [268, 344]
# [INFO] Model Probability: 0.010354185828097823  Loop: 15000   KeyPoint Top Left Corner (x,y) [380, 368]
# [INFO] Model Probability: 0.026140042613007942  Loop: 16000   KeyPoint Top Left Corner (x,y) [492, 392]
# [INFO] Model Probability: 0.014133912865597712  Loop: 18000   KeyPoint Top Left Corner (x,y) [68, 444]
# [INFO] Model Probability: 0.014600154905033979  Loop: 19000   KeyPoint Top Left Corner (x,y) [180, 468]
# [INFO] Model Probability: 0.016250834885002362  Loop: 20000   KeyPoint Top Left Corner (x,y) [292, 492]
# [INFO] Model Probability: 0.01963477498075333  Loop: 21000   KeyPoint Top Left Corner (x,y) [404, 516]
# [INFO] Model Probability: 0.012477434831766434  Loop: 22000   KeyPoint Top Left Corner (x,y) [516, 540]
# [INFO] Model Probability: 0.017447406230427502  Loop: 24000   KeyPoint Top Left Corner (x,y) [92, 592]
# [INFO] Model Probability: 0.010351919395842782  Loop: 25000   KeyPoint Top Left Corner (x,y) [204, 616]
# [INFO] Model Probability: 0.01460645916675599  Loop: 26000   KeyPoint Top Left Corner (x,y) [316, 640]
# [INFO] Model Probability: 0.0834761030162719  Loop: 27000   KeyPoint Top Left Corner (x,y) [428, 664]
# [INFO] Model Probability: 0.0347347936269705  Loop: 28000   KeyPoint Top Left Corner (x,y) [540, 688]
# [INFO] Model Probability: 0.013725515520955267  Loop: 29000   KeyPoint Top Left Corner (x,y) [4, 716]
# [INFO] Model Probability: 0.03893657387478783  Loop: 30000   KeyPoint Top Left Corner (x,y) [116, 740]
# [INFO] Model Probability: 0.013290777445600806  Loop: 31000   KeyPoint Top Left Corner (x,y) [228, 764]
# [INFO] Investigating layer 1 at scale: 1.5018115942028984
# [INFO] Model Probability: 0.00825829651751349  Loop: 1000   KeyPoint Top Left Corner (x,y) [108, 36]
# [INFO] Model Probability: 0.5869622881813485  Loop: 2000   KeyPoint Top Left Corner (x,y) [220, 72]
# [INFO] Model Probability: 0.003375681007959127  Loop: 3000   KeyPoint Top Left Corner (x,y) [332, 108]
# [INFO] Model Probability: 0.02288112093945525  Loop: 4000   KeyPoint Top Left Corner (x,y) [12, 148]
# [INFO] Model Probability: 0.0209363126308745  Loop: 5000   KeyPoint Top Left Corner (x,y) [124, 184]
# [INFO] Model Probability: 0.005232921274212151  Loop: 6000   KeyPoint Top Left Corner (x,y) [236, 220]
# [INFO] Model Probability: 0.013943341541807135  Loop: 8000   KeyPoint Top Left Corner (x,y) [28, 296]
# [INFO] Model Probability: 0.06443508465447009  Loop: 9000   KeyPoint Top Left Corner (x,y) [140, 332]
# [INFO] Model Probability: 0.04511023341693972  Loop: 10000   KeyPoint Top Left Corner (x,y) [252, 368]
# [INFO] Model Probability: 0.014520259970309297  Loop: 12000   KeyPoint Top Left Corner (x,y) [44, 444]
# [INFO] Model Probability: 0.017414975811425582  Loop: 13000   KeyPoint Top Left Corner (x,y) [156, 480]
# [INFO] Investigating layer 2 at scale: 2.2527173913043477
# [INFO] Model Probability: 0.011219695846025753  Loop: 3000   KeyPoint Top Left Corner (x,y) [188, 164]
# [INFO] Model Probability: 0.03830772400323331  Loop: 4000   KeyPoint Top Left Corner (x,y) [156, 220]
# [INFO] Model Probability: 0.046910513654100275  Loop: 5000   KeyPoint Top Left Corner (x,y) [124, 276]
# [INFO] Investigating layer 3 at scale: 3.3836734693877553
# [INFO] Investigating layer 4 at scale: 5.085889570552148
# [INFO] 593 boxes were found with a probablility > 0.51
# [INFO] Scanning file: M:\DataSets\Caltech256\256_ObjectCategories\013.birdbath\013_0065.jpg
# [INFO] Investigating layer 0 at scale: 1.0
# [INFO] Investigating layer 1 at scale: 1.502824858757062
# [INFO] Investigating layer 2 at scale: 2.2542372881355934
# [INFO] Investigating layer 3 at scale: 3.41025641025641
# [INFO] 42 boxes were found with a probablility > 0.51
# [INFO] Scanning file: M:\DataSets\Caltech256\256_ObjectCategories\013.birdbath\013_0054.jpg
# [INFO] Investigating layer 0 at scale: 1.0
# [INFO] Model Probability: 0.0023131078728595798  Loop: 1000   KeyPoint Top Left Corner (x,y) [284, 32]
# [INFO] Model Probability: 0.01023591097699569  Loop: 2000   KeyPoint Top Left Corner (x,y) [108, 68]
# [INFO] Model Probability: 0.004802019804518122  Loop: 4000   KeyPoint Top Left Corner (x,y) [220, 136]
# [INFO] Model Probability: 0.006516673051041639  Loop: 5000   KeyPoint Top Left Corner (x,y) [44, 172]
# [INFO] Model Probability: 0.00652849334080781  Loop: 6000   KeyPoint Top Left Corner (x,y) [332, 204]
# [INFO] Model Probability: 0.012956838744068467  Loop: 7000   KeyPoint Top Left Corner (x,y) [156, 240]
# [INFO] Investigating layer 1 at scale: 1.5
# [INFO] Model Probability: 0.012286731730071396  Loop: 2000   KeyPoint Top Left Corner (x,y) [196, 100]
# [INFO] Model Probability: 0.024648103639854133  Loop: 3000   KeyPoint Top Left Corner (x,y) [140, 152]
# [INFO] Investigating layer 2 at scale: 2.25974025974026
# [INFO] Model Probability: 0.002105636940821272  Loop: 1000   KeyPoint Top Left Corner (x,y) [44, 76]
# [INFO] Investigating layer 3 at scale: 3.411764705882353
# [INFO] Investigating layer 4 at scale: 5.117647058823529
# [INFO] 11 boxes were found with a probablility > 0.51
# [INFO] Scanning file: M:\DataSets\Caltech256\256_ObjectCategories\013.birdbath\013_0058.jpg
# [INFO] Investigating layer 0 at scale: 1.0
# [INFO] Model Probability: 0.0021135677060407482  Loop: 1000   KeyPoint Top Left Corner (x,y) [348, 32]
# [INFO] Model Probability: 0.009060659271768643  Loop: 2000   KeyPoint Top Left Corner (x,y) [244, 68]
# [INFO] Model Probability: 0.0026086529397897963  Loop: 3000   KeyPoint Top Left Corner (x,y) [140, 104]
# [INFO] Model Probability: 0.014759111377135212  Loop: 4000   KeyPoint Top Left Corner (x,y) [36, 140]
# [INFO] Model Probability: 0.00204653565511879  Loop: 6000   KeyPoint Top Left Corner (x,y) [284, 208]
# [INFO] Model Probability: 0.00940049383083916  Loop: 7000   KeyPoint Top Left Corner (x,y) [180, 244]
# [INFO] Investigating layer 1 at scale: 1.5
# [INFO] Model Probability: 0.010902203349272239  Loop: 1000   KeyPoint Top Left Corner (x,y) [44, 52]
# [INFO] Model Probability: 0.06840204906288117  Loop: 2000   KeyPoint Top Left Corner (x,y) [92, 104]
# [INFO] Investigating layer 2 at scale: 2.25
# [INFO] Investigating layer 3 at scale: 3.3870967741935485
# [INFO] 271 boxes were found with a probablility > 0.51
# [INFO] dumping hard negatives to file...
# Finished Dumping Data into:

# %%
train_model(conf,1)
# Out:
# [INFO] loading dataset...
# Example of a data point. Feature: [ 0.03051709  0.00742838  0.04882491 ...,  0.00128204  0.          0.        ] and Label 1.0
# [INFO] loading hard negatives...
# [INFO] best hyperparameters: {'C': 1.0}
# [INFO] training classifier...
#              precision    recall  f1-score   support
#
#        -1.0       0.99      1.00      0.99      5064
#         1.0       1.00      0.22      0.37        67
#
# avg / total       0.99      0.99      0.99      5131
#
# [INFO] dumping classifier...
# Finished.  SVD is saved as: M:\DataSets\2016_USATF_Sprint_TrainingDataset\svm_model.cpickle

# %%
(hardData, hardLabels) = load_dataset(conf["features_path"], "hard_negatives")

# %%
hardData.shape
# Out:
# (5014, 11340)

# %% [markdown]
# ## Testing Trained Model
# This step involves
#     1. Looping over all layers of the image pyramid.
#     2. Applying our sliding window at each layer of the pyramid.
#     3. Extracting HOG features from each window.
#     4. Passing the extracted HOG feature vectors to our model for classification.
#     5. Maintaining a list of bounding boxes that are reported to contain an object of interest with sufficient probability

# %%
#TestFile="M:\\DataSets\\SprintPhotos_Small\\dsc_4153_01.jpg"
TestFile="M:\\DataSets\\SprintPhotos_Small\\dsc_3332.jpg"
test_model(conf,TestFile,SW)
# Out:
# <__main__.ObjectDetector object at 0x000002921F371828>
# Detecting the object
# [INFO] Investigating layer 0 at scale: 1.0
# [INFO] Investigating layer 1 at scale: 1.5037593984962405
# [INFO] Investigating layer 2 at scale: 2.2598870056497176
# [INFO] Model Probability: 1.0000000994736041e-07  Loop: 1000   KeyPoint Top Left Corner (x,y) [36, 88]
# [INFO] Investigating layer 3 at scale: 3.389830508474576
# Finished detecting the object
